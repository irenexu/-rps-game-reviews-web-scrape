# %% [markdown]
# # NLP Project - Web Scraping and Text Analysis of Game Reviews on Rock Paper Shotgun
# ## Part I. Build Dataset
# ### Step 3 - Scrape webpages using bs4 & loops to get content of all the game-related reviews

# %% [markdown]
# #### 1. Extract links & titles from `rps_links_output_file.json`

# %%
import requests
from bs4 import BeautifulSoup
import json
import re
import json
from datetime import datetime

# %%
# Open the JSON file
with open('rps_links_output_file.json', 'r') as file:
    # Load the JSON content into a variable
    data = json.load(file)

# %%
print(f"{len(data)} review links have been scrapped from rps - until 1/12/2023")
# Out:
# 2388 review links have been scrapped from rps - until 1/12/2023

# %% [markdown]
# #### 2. Data Pre-Processing - obtain game reviews from the past 3.5 years:
# 1. remove all reviews published before 1/6/2020; retain only those from the past three and half years to ensure the dataset reflects the latest information. Many older posts prior mid 2020 lack details about developers and briefs, and the varied (inconsistent) formatting substantially increases the time required for accurate data extraction and cleaning.
# 2. remove all the non game related reviews, e.g., hardware, CPU

# %%
reviews_in_recent_years = []

for dict in data:
    response = requests.get(url=dict['URL'])
    html_code = response.text
    soup = BeautifulSoup(html_code, "html.parser")

    # ChatGpt used here asking about how to compare dates using python
    # convert str to datetime object 
    # reference code also found in: https://stackoverflow.com/questions/72702859/use-python-datetime-strptime
    date = soup.find("time").get('datetime')[:10]
    datetime_to_compare = datetime.strptime('2020-06-01', '%Y-%m-%d')

    # extract topics provided at the end of review - same for all webpages
    topic = soup.select("#content_above > .page_content span.tagged_with_item.tagged_with_item--secondary a")
    label = [item.text for item in topic]

    if datetime.strptime(date, '%Y-%m-%d') > datetime_to_compare:
        if "Hardware" not in label and "CPU" not in label:
            reviews_in_recent_years.append(dict)
            print(date)
            print(label)
    else:
        break
# Out:
# 2023-11-27
# ['Action Adventure', 'Historical', 'Indie', 'PC', 'Strategy: Real-Time Strategy', 'Wot I Think']
# 2023-11-27
# ['Management', 'PC', 'Simulation', 'Strategy', 'The Station', 'Thunderful', 'Thunderful Publishing', 'Wot I Think']
# 2023-11-23
# ['Action Adventure', 'Indie', 'RPG', 'Sports', 'Strategy: Turn-Based Strategy', 'Wot I Think']
# 2023-11-21
# ['Action Adventure', 'Microids', 'PC', 'Platformer', 'Wot I Think']
# 2023-11-17
# ['Action Adventure', 'Darya Noghani', 'Indie', 'RPG', 'Wot I Think']
# 2023-11-17
# ['PC', 'PS4', 'PS5', 'Shooter', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-11-16
# ['Action Adventure', 'Exploration', 'Indie', 'Moon Lagoon', 'PC', 'Science Fiction', 'Secret Mode', 'Story Rich', 'Wot I Think']
# 2023-11-15
# ['Artefacts Studio', 'Dear Villagers', 'PC', 'Simulation', 'Wot I Think']
# 2023-11-15
# ['Action Adventure', 'Indie', 'PC', 'Platformer', 'Puzzle', 'Raw Fury', 'Reviews', 'Wot I Think']
# 2023-11-14
# ['Atlus', 'PC', 'RPG', 'Sega', 'SEGA of America', 'Simulation', 'Strategy', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-11-14
# ['Fantasy', 'Frontier Developments', 'Games Workshop', 'PC', 'PS5', 'Strategy', 'Strategy: Real-Time Strategy', 'Wot I Think', 'Xbox Series X/S']
# 2023-11-09
# ['Activision', 'PC', 'PS4', 'PS5', 'Shooter', 'Sledgehammer Games', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-11-09
# ['Action Adventure', 'Hack & Slash', 'RPG', 'Ryu Ga Gotoku Studio', 'Sega', 'Wot I Think']
# 2023-11-08
# ['Brace Yourself Games', 'Card Games', 'Indie', 'Puzzle', 'Rocket Rat Games', 'RPG', 'Strategy', 'Wot I Think']
# 2023-11-07
# ['Bestest Bests', 'Croteam', 'Devolver Digital', 'Platformer', 'Puzzle', 'Science Fiction', 'Wot I Think']
# 2023-11-02
# ['Management', 'Sega', 'Sports', 'Sports Interactive', 'Wot I Think']
# 2023-11-02
# ['11 Bit Studios', 'Action Adventure', 'Indie', 'PC', 'PS5', 'Science Fiction', 'Starward Industries', 'Wot I Think', 'Xbox Series X/S']
# 2023-11-02
# ['Action Adventure', 'Nacon', 'PC', 'PS4', 'PS5', 'Shooter', 'Teyon', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-11-01
# ['Action Adventure', 'PC', 'PS5', 'Remedy Entertainment', 'Shooter', 'Wot I Think', 'Xbox Series X/S']
# 2023-11-01
# ['Action Adventure', 'Annapurna Interactive', 'Outerloop Games', 'Platformer', 'RPG', 'Wot I Think']
# 2023-10-31
# ['Action Adventure', 'Bestest Bests', "Don't Nod", 'Exploration', 'Fantasy', 'Wot I Think']
# 2023-10-31
# ['Action Adventure', 'Free Range Games', 'North Beach Games', 'PC', 'Survival & Crafting', 'Wot I Think']
# 2023-10-30
# ['Action Adventure', 'Indie', 'Puzzle', 'Tequila Works', 'Wot I Think']
# 2023-10-23
# ['Arcade', 'Grapefrukt Games', 'Puzzle', 'Simulation', 'Sports', 'Wot I Think']
# 2023-10-23
# ['505 Games', 'Action Adventure', 'Hack & Slash', 'Indie', 'One More Level', 'OneMoreLevel', 'Platformer', 'Science Fiction', 'Shooter', 'Shooter: First Person', 'Strategy', 'Wot I Think']
# 2023-10-19
# ['Colossal Order', 'Management', 'Paradox Interactive', 'PC', 'PS5', 'Sandbox', 'Simulation', 'Strategy', 'Wot I Think', 'Xbox Series X/S']
# 2023-10-19
# ['Door 407', 'PC', 'Puzzle', 'Wot I Think']
# 2023-10-18
# ['Action Adventure', 'Bestest Bests', 'Horror', 'Indie', 'Mac', 'PC', 'Point and Click', 'RPG', 'Strategy: Turn-Based Strategy', 'Wot I Think', 'Ysbryd Games']
# 2023-10-16
# ['AMPLITUDE Studios', 'Bestest Bests', 'RPG', 'Sega', 'Strategy', 'Wot I Think']
# 2023-10-12
# ['Mac', 'Nimble Giant Entertainment', 'Paradox Interactive', 'PC', 'Science Fiction', 'Strategy', 'Strategy: Grand Strategy/4X', 'Wot I Think']
# 2023-10-12
# ['Android', 'Bandai Namco Entertainment', 'CI Games', 'City Interactive', 'Hack & Slash', 'HexWorks', 'iOS', 'PC', 'PS4', 'RPG', 'Soulslike', 'Splash Damage', 'WarChest', 'Wot I Think', 'Xbox One']
# 2023-10-12
# ['Action Adventure', 'Die Gute Fabrik', 'Indie', 'Nintendo Switch', 'PC', 'PS5', 'Story Rich', 'Wot I Think']
# 2023-10-10
# ['Creative Assembly', 'Historical', 'PC', 'Sandbox', 'Sega', 'Strategy', 'Strategy: Grand Strategy/4X', 'Strategy: Real-Time Strategy', 'Wot I Think']
# 2023-10-05
# ['Harebrained Schemes', 'Paradox Interactive', 'PC', 'Stealth', 'Story Rich', 'Strategy', 'Wot I Think', 'Xbox Series X/S']
# 2023-10-04
# ['PC', 'Shooter: First Person', 'Valve Software', 'Wot I Think']
# 2023-10-04
# ['Action Adventure', 'PC', 'PS4', 'PS5', 'Ubisoft Bordeaux', 'Ubisoft Entertainment', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-10-03
# ['Bestest Bests', 'Galaxy Grove', 'Indie', 'Prismatika', 'Puzzle', 'Reviews', 'Simulation', 'Wot I Think']
# 2023-09-28
# ['Action Adventure', 'Bestest Bests', 'Geometric Interactive', 'Indie', 'Puzzle', 'Wot I Think']
# 2023-09-26
# ['Indie', 'Indiescovery', 'Reviews', 'Shooter', 'Strange Scaffold', 'Wot I Think']
# 2023-09-25
# ['Action Adventure', 'Humble Bundle', 'Humble Games', 'Indie', 'Meowza Games', 'Simulation', 'Wot I Think']
# 2023-09-22
# ['Overkill Software', 'PC', 'Prime Matter', 'PS5', 'Shooter', 'Starbreeze Studios', 'Wot I Think', 'Xbox Series X/S']
# 2023-09-20
# ['Action Adventure', 'Bestest Bests', 'CD Projekt', 'CD Projekt RED', 'PC', 'PS4', 'PS5', 'RPG', 'Shooter', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-09-19
# ['Neowiz', 'PC', 'PS4', 'PS5', 'RPG', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-09-18
# ['Fighting', 'NetherRealm Studios', 'Nintendo Switch', 'PC', 'PS5', 'Warner Bros. Games', 'Wot I Think', 'Xbox Series X/S']
# 2023-09-15
# ['Action Adventure', 'Indie', 'Nintendo Switch', 'PC', 'Platformer', 'Sports', 'Team Reptile', 'Wot I Think']
# 2023-09-13
# ['Funcom', 'PC', 'Shiro Games', 'Strategy', 'Strategy: Real-Time Strategy', 'Wot I Think']
# 2023-09-13
# ['Action Adventure', 'Devolver Digital', 'Indie', 'Platformer', 'Wot I Think']
# 2023-09-13
# ['Assemble Entertainment', 'Point and Click', 'Puzzle', 'SenAm Games', 'Visual Novel & Dating', 'Wot I Think']
# 2023-09-12
# ['Action Adventure', 'Aspyr', 'Beamdog', 'PC', 'Wot I Think']
# 2023-09-07
# ['Anime', 'Befun Studio', 'Fantasy', 'Indie', 'Spiral Up Games', 'Strategy', 'Visual Novel & Dating', 'Wot I Think']
# 2023-09-06
# ['Bethesda Game Studios', 'Bethesda Softworks', 'Open World', 'PC', 'RPG', 'Science Fiction', 'Shooter: First Person', 'Wot I Think', 'Xbox Series X/S']
# 2023-08-31
# ['PICO game', 'Pico-8', 'Science Fiction', 'Space Combat', 'Wot I Think']
# 2023-08-28
# ['Action Adventure', 'Indie', 'PC', 'RPG', 'Sabotage Studio', 'Strategy: Turn-Based Strategy', 'Wot I Think']
# 2023-08-23
# ['Action Adventure', 'Bandai Namco Entertainment', 'FromSoftware', 'PC', 'PS4', 'PS5', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-08-22
# ['Action Adventure', 'Dear Villagers', 'Fallen Leaf Studio', 'PC', 'Wot I Think']
# 2023-08-22
# ['Ascendant Studios', 'Electronic Arts', 'Fantasy', 'PC', 'Shooter', 'Wot I Think']
# 2023-08-21
# ['Bestest Bests', 'Kitfox Games', 'PC', 'Simulation', 'Story Rich', 'Strategy', 'Wot I Think']
# 2023-08-17
# ['Indie', 'Metroidvania', 'Nintendo Switch', 'PC', 'Platformer', 'Team17', 'The Game Kitchen', 'Wot I Think']
# 2023-08-16
# ['Deconstructeam', 'Devolver Digital', 'Fantasy', 'Indie', 'PC', 'Story Rich', 'Wot I Think']
# 2023-08-16
# ['Bestest Bests', 'Indie', 'Kowloon Nights', 'Mimimi Games', 'PC', 'PS5', 'Simulation', 'Stealth', 'Strategy', 'Strategy: Real-Time Strategy', 'Wot I Think', 'Xbox Series X/S']
# 2023-08-15
# ['Action Adventure', 'Covenant.dev', 'Indie', 'PC', 'RPG', 'Simulation', 'Strategy', 'Team17', 'Wot I Think']
# 2023-08-10
# ['Action Adventure', 'Bestest Bests', 'Larian Studios', 'PC', 'PS5', 'RPG', 'Strategy', 'Strategy: Turn-Based Strategy', 'Wot I Think', 'Xbox Series X/S']
# 2023-08-10
# ['Apogee Entertainment', 'Indie', 'Shooter', 'Trigger Happy Interactive', 'Wot I Think']
# 2023-08-09
# ['Action Adventure', 'Deck13 Interactive', 'Focus Entertainment', 'PC', 'PS5', 'RPG', 'Wot I Think', 'Xbox Series X/S']
# 2023-08-09
# ['Action Adventure', 'Humble Games', 'PC', 'RPG', 'Story Rich', 'Summerfall Studios', 'Visual Novel & Dating', 'Wot I Think']
# 2023-08-07
# ['Action Adventure', 'Bestest Bests', 'Indie', 'kinmoku', 'Simulation', 'Wot I Think']
# 2023-07-31
# ['Action Adventure', 'Indie', 'Puzzle', 'Simulation', 'Visai Games', 'Visual Novel & Dating', 'Wot I Think']
# 2023-07-27
# ['Frontier Developments', 'PC', 'PS4', 'PS5', 'Racing Simulation', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-07-25
# ['Fantasy', 'Historical', 'Indie', 'Ishtar Games', 'Management', 'PC', 'Romance', 'Simulation', 'Strategy', 'Wot I Think']
# 2023-07-21
# ['Bestest Bests', 'Indie', 'Kodera Software', 'Simulation', 'Wot I Think']
# 2023-07-20
# ['Capcom', 'PC', 'PS4', 'PS5', 'Shooter', 'Strategy', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-07-20
# ['Action Adventure', 'Bestest Bests', 'Gearbox Publishing', 'Gunfire Games', 'PC', 'RPG', 'Shooter', 'Wot I Think']
# 2023-07-20
# ['Action Adventure', 'Capybara Games', 'iOS', 'Nintendo DS', 'PC', 'PS3', 'Puzzle', 'RPG', 'Strategy', 'Tag Games', 'Ubisoft', 'Wot I Think', 'Xbox 360']
# 2023-07-18
# ['Antfood', 'Bestest Bests', 'Buck', 'Hawthorn Games', 'PC', 'Puzzle', 'Roguelike', 'Strategy', 'Wot I Think']
# 2023-07-18
# ['Action Adventure', 'Indie', 'Indiescovery', 'OutOfTheBit Ltd', 'PC', 'Platformer', 'Puzzle', 'Story Rich', 'Wot I Think']
# 2023-07-17
# ['Capcom', 'PC', 'PS4', 'PS5', 'Science Fiction', 'Shooter', 'Shooter: Third Person', 'Strategy', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-07-17
# ['Bestest Bests', 'PC', 'Puzzle', 'Sad Owl Studios', 'Thunderful Publishing', 'Wot I Think']
# 2023-07-13
# ['Haemimont Games', 'RPG', 'Strategy', 'Strategy: Turn-Based Strategy', 'THQ', 'THQ Nordic', 'Wot I Think']
# 2023-07-12
# ['Action Adventure', 'Indie', 'MWM Interactive', 'Netflix, Inc.', 'Night School Studio', 'Nintendo Switch', 'PC', 'PS4', 'PS5', 'Puzzle', 'Simulation', 'Wot I Think']
# 2023-06-30
# ['Action Adventure', 'Day 1 Studios', 'Horror', 'I CAN SEE MY LEGS', 'Indie', 'Monolith Productions', 'PC', 'PS3', 'Shooter', 'Simulation', 'Team17', 'Trepang Studios', 'Vivendi Games', 'Wot I Think', 'Xbox 360']
# 2023-06-30
# ['Action Adventure', 'Bestest Bests', 'Capcom', 'iOS', 'Nintendo DS', 'Puzzle', 'Wot I Think']
# 2023-06-19
# ['Action Adventure', 'Focus Entertainment', 'PC', 'PS4', 'PS5', 'Strategy', 'Tindalos Interactive', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-06-16
# ['Action Adventure', 'Focus Entertainment', 'Indie', 'PC', 'Un Je Ne Sais Quoi', 'Wot I Think']
# 2023-06-15
# ['Bandai Namco Entertainment', 'PC', 'PS5', 'Simulation', 'Strategy', 'Xbox Series X/S']
# 2023-06-08
# ['Failbetter Games', 'Indie', 'PC', 'RPG', 'Visual Novel & Dating', 'Wot I Think']
# 2023-06-06
# ['Action Adventure', 'Frictional Games', 'Indie', 'PC', 'Puzzle', 'Shooter', 'Wot I Think']
# 2023-06-01
# ['Action Adventure', 'Comedy', 'Indie', 'Jay Tholen', 'No More Robots', 'PC', 'Point and Click', 'Puzzle', 'RPG', 'Shooter', 'Shooter: First Person', 'Simulation']
# 2023-05-31
# ['Armor Games Studios', 'Horror', 'Indie', 'Indiescovery', 'Puzzle', 'Vertical Reach', 'Wot I Think']
# 2023-05-30
# ['Blizzard Entertainment', 'Blockbuster', 'Hack & Slash', 'PC', 'PS4', 'PS5', 'RPG', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-05-30
# ['Arcade', 'Capcom', 'Fighting', 'PS5', 'Wot I Think']
# 2023-05-29
# ['Bestest Bests', 'Electronic Arts', 'Looking Glass Studios', 'Nightdive Studios', 'PC', 'Prime Matter', 'RPG', 'Shooter', 'Wot I Think']
# 2023-05-25
# ['Action Adventure', 'Daedalic Entertainment', 'Nacon', 'Nintendo Switch', 'PC', 'PS4', 'PS5', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-05-24
# ['505 Games', 'Action Adventure', 'PC', 'Strategy', 'The Bearded Ladies', 'Wot I Think']
# 2023-05-23
# ['Arcade', 'Auroch Digital', 'Entertainment Focus', 'Focus Entertainment', 'Indie', 'PC', 'Shooter', 'Wot I Think']
# 2023-05-23
# ['Enhance Media', 'PS4', 'PS5', 'Puzzle', 'Wot I Think']
# 2023-05-22
# ['Action Adventure', 'Indie', 'Platformer', 'Puzzle', 'Thunderful', 'Thunderful Publishing', 'Wishfully', 'Wot I Think']
# 2023-05-19
# ['PC', 'Shooter', 'Spytihněv', 'Wot I Think']
# 2023-05-18
# ['2K', 'Nintendo Switch', 'Open World', 'PC', 'PS4', 'PS5', 'Racing', 'Visual Concepts', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-05-09
# ['Action Adventure', 'Indie', 'PC', 'Red Hook Studios', 'Strategy', 'Strategy: Turn-Based Strategy', 'Wot I Think']
# 2023-05-05
# ['Action Adventure', 'Arkane Austin', 'Arkane Studios', 'Bethesda Game Studios', 'Open World', 'PC', 'RPG', 'Shooter', 'Wot I Think', 'Xbox Series X/S']
# 2023-04-27
# ['Paradox Development Studio', 'Paradox Interactive', 'PC', 'PS5', 'RPG', 'RPG: Turn-based', 'Strategy', 'Strategy: Grand Strategy/4X', 'Strategy: Turn-Based Strategy', 'Triumph Studios', 'Wot I Think', 'Xbox Series X/S']
# 2023-04-26
# ['Action Adventure', 'Bytten Studio', 'Indie', 'Raw Fury', 'RPG', 'Wot I Think']
# 2023-04-26
# ['Action Adventure', 'Blockbuster', 'Electronic Arts', 'PC', 'Respawn Entertainment', 'Wot I Think']
# 2023-04-26
# ['Action Adventure', 'Android', 'Anime', 'HoYoVerse', 'iOS', 'MiHoYo Limited', 'PC', 'RPG', 'Strategy: Turn-Based Strategy', 'Wot I Think']
# 2023-04-24
# ['Frontier Foundry', 'Haemimont Games', 'PC', 'Simulation', 'Strategy', 'Strategy: Builder', 'Survival & Crafting', 'Wot I Think']
# 2023-04-19
# ['GrabTheGames', 'PC', 'Strategy: Builder', 'Turquoise Revival Games']
# 2023-04-19
# ['Action Adventure', 'Indie', 'Simulation', 'Toge Productions', 'Visual Novel & Dating', 'Wot I Think']
# 2023-04-18
# ['Action Adventure', 'Blockbuster', 'Dambuster Studios', 'Deep Silver', 'Hack & Slash', 'PC', 'PS4', 'RPG', 'Shooter', 'Xbox One']
# 2023-04-14
# ['Action Adventure', 'Blackbird Interactive', 'Mojang', 'Strategy: Real-Time Strategy', 'Wot I Think']
# 2023-04-12
# ['Action Adventure', 'Frogwares', 'Horror', 'Indie', 'Nintendo Switch', 'PC', 'PS4', 'PS5', 'Puzzle', 'Wot I Think', 'Xbox One', 'Xbox Series X/S']
# 2023-04-12
# ['Shiro Games', 'Shiro Unlimited', 'Wot I Think']
# 2023-04-06
# ['Digixart', 'Indie', 'Story Rich', 'Wot I Think']
# 2023-04-04
# ['Indie', 'Indiescovery', 'ROCKFISH Games', 'Simulation', 'Wot I Think']
# 2023-03-30
# ['Card Games', 'Chucklefish Games', 'Deadpan Games', 'Gaziter', 'Indie', 'Roguelike', 'Wot I Think']
# 2023-03-30
# ['Exploration', 'Oiffy', 'Puzzle', 'Wired Productions', 'Wolf & Wood Interactive Ltd', 'Wot I Think']
# 2023-03-28
# ['505 Games', 'Blockbuster', 'Indie', 'Ingame Studios', 'Shooter', 'Wot I Think']
# 2023-03-27
# ['Devolver Digital', 'Free Lives', 'Puzzle', 'Wot I Think']
# 2023-03-27
# ['Blockbuster', 'Frontier Foundry', 'Petroglyph', 'Strategy', 'Wot I Think']
# 2023-03-23
# ['Bestest Bests', 'Black Salt Games', 'Exploration', 'Horror', 'Indie', 'Management', 'Story Rich', 'Team17', 'Wot I Think']
# 2023-03-22
# ['Annapurna Interactive', 'Daniel Benmergui', 'Indie', 'Indiescovery', 'Puzzle', 'Wot I Think']
# 2023-03-21
# ['Action Adventure', 'Awaceb', 'Bestest Bests', 'Exploration', 'Indie', 'Indiescovery', 'Kepler Interactive', 'Story Rich', 'Wot I Think']
# 2023-03-17
# ['Bestest Bests', 'Blockbuster', 'Capcom', 'Horror', 'Shooter', 'Shooter: Third Person', 'Wot I Think']
# 2023-03-15
# ['Bestest Bests', 'Horror', 'Point and Click', 'Puzzle', 'Square Enix', 'Story Rich', 'Wot I Think']
# 2023-03-14
# ['Bestest Bests', 'Indie', 'Indiescovery', 'Story Rich', 'The Pixel Hunt', 'Visual Novel & Dating', 'Wot I Think']
# 2023-03-10
# ['Horror', 'Koei Tecmo', 'Wot I Think']
# 2023-03-09
# ['Action Adventure', 'Bedtime Digital Games', 'Fantasy', 'Wot I Think']
# 2023-03-07
# ['Indie', 'Indiescovery', 'Life Simulation', 'Management', 'Pomelo Games', 'Strategy', 'Wot I Think']
# 2023-03-02
# ['Action Adventure', 'Koei Tecmo', 'RPG', 'Team Ninja', 'Wot I Think']
# 2023-03-01
# ['early access', 'Endnight Games', 'Horror', 'Survival & Crafting', 'Wot I Think']
# 2023-02-28
# ['Brace Yourself Games', 'Strategy', 'Strategy: Turn-Based Strategy', 'Wot I Think']
# 2023-02-27
# ['early access', 'Intercept', 'Private Division', 'Sandbox', 'Science Fiction', 'Simulation', 'Wot I Think']
# 2023-02-24
# ['Strategy', 'Strategy: Builder', 'Strategy: Real-Time Strategy', 'Ubisoft', 'Ubisoft Blue Byte', 'Wot I Think']
# 2023-02-23
# ['Action Adventure', 'Blockbuster', 'EA Originals', 'Fantasy', 'Hack & Slash', 'Omega Force', 'RPG', 'Wot I Think']
# 2023-02-23
# ['Action Adventure', 'Bellular Games', 'Fellow Traveller', 'Indiescovery', 'Survival & Crafting', 'Wot I Think']
# 2023-02-20
# ['Historical', 'Relic Entertainment', 'Sega', 'Strategy', 'Wot I Think']
# 2023-02-20
# ['Indie', 'Indiescovery', 'Madison Karrh', 'Puzzle', 'Wings', 'Wot I Think']
# 2023-02-20
# ['Focus Entertainment', 'Mundfish', 'Open World', 'Shooter', 'Wot I Think']
# 2023-02-17
# ['Action Adventure', 'JRPG', 'Ryu Ga Gotoku Studio', 'Sega', 'Wot I Think']
# 2023-02-17
# ['Acquire Corp', 'JRPG', 'Wot I Think']
# 2023-02-15
# ['Action Adventure', 'Bestest Bests', 'Climax Studios', 'Housemarque', 'PlayStation', 'Roguelike', 'Wot I Think']
# 2023-02-15
# ['DotEmu', 'Historical', 'Strategy', 'Triskell Interactive', 'Wot I Think']
# 2023-02-14
# ['Casus Ludi', 'Gearbox Publishing', 'Indie', 'Platformer', 'Wot I Think']
# 2023-02-14
# ['110 Industries SA', 'Action Adventure', 'Hack & Slash', 'Soleil Ltd.', 'Wot I Think']
# 2023-02-10
# ['Brace Yourself Games', 'Science Fiction', 'Strategy: Builder', 'Wot I Think']
# 2023-02-02
# ['Action Adventure', 'Frontier Foundry', 'Indie', 'KeokeN Interactive', 'Science Fiction', 'Story Rich', 'Wot I Think']
# 2023-02-02
# ['Action Adventure', 'Bethesda Game Studios', 'Rhythm', 'Tango Gameworks', 'Wot I Think']
# 2023-01-31
# ['Blockbuster', 'Luminous Productions', 'Open World', 'RPG', 'Square Enix', 'Wot I Think']
# 2023-01-26
# ['Action Adventure', 'Blockbuster', 'Horror', 'Motive Studio', 'Shooter: Third Person']
# 2023-01-26
# ['Bestest Bests', 'Exploration', 'Scavengers Studio', 'Story Rich', 'Wot I Think']
# 2023-01-24
# ['Game Source Studio', 'Iceburg Interactive', 'Indie', 'Strategy', 'Wot I Think']
# 2023-01-18
# ['Bestest Bests', 'Indie', 'Indiescovery', 'Mojiken Studio', 'Romance', 'Story Rich', 'Toge Productions', 'Wot I Think']
# 2023-01-16
# ['Andriy Bychkovskyi', 'Crytivo', 'Science Fiction', 'Simulation', 'Strategy: Builder', 'Wot I Think']
# 2023-01-11
# ['Digital Reef Games', 'Management', 'Overseer Games', 'Simulation', 'Survival & Crafting', 'Wot I Think']
# 2022-12-15
# ['Bestest Bests', 'Indie', 'MegaWobble', 'Open World', 'Playtonic Friends', 'Wot I Think']
# 2022-12-14
# ['Fantasy', 'Fatshark', 'Horror', 'Shooter', 'Wot I Think']
# 2022-12-13
# ['Action Adventure', 'Blockbuster', 'JRPG', 'Tose Co Ltd', 'Wot I Think']
# 2022-12-09
# ['Horror', 'Two Star Games', 'Wot I Think']
# 2022-12-07
# ['Bay 12 Games', 'Fantasy', 'Indie', 'Kitfox Games', 'Sandbox', 'Strategy', 'Wot I Think']
# 2022-12-07
# ['Bulwark Studios', 'Kasedo Games', 'Science Fiction', 'Wot I Think']
# 2022-12-05
# ['PixelCount Studios', 'Wot I Think']
# 2022-12-02
# ['Horror', 'Krafton', 'Shooter', 'Striking Distance Studios', 'Wot I Think']
# 2022-11-30
# ['2K', 'Bestest Bests', 'Blockbuster', 'Card Games', 'Firaxis Games', 'Strategy', 'Wot I Think']
# 2022-11-23
# ['Activision Blizzard', 'Blockbuster', 'Infinity Ward', 'Raven Software', 'Shooter', 'Shooter: First Person', 'Wot I Think']
# 2022-11-17
# ['Action Adventure', 'Bandai Namco Entertainment', 'Horror', 'Supermassive Games', 'The Dark Pictures Anthology', 'Wot I Think']
# 2022-11-16
# ['Coffee Stain North', 'Coffee Stain Publishing', 'Comedy', 'Simulation', 'Wot I Think']
# 2022-11-15
# ['Action Adventure', 'Bestest Bests', 'Blockbuster', 'Historical', 'Indie', 'Mystery', 'Obsidian Entertainment', 'Story Rich', 'Wot I Think', 'Xbox Game Studios']
# 2022-11-15
# ['Action Adventure', 'Jumpship', 'Science Fiction', 'Wot I Think']
# 2022-11-14
# ['Action Adventure', 'Platformer', 'Sega', 'Sonic Team', 'Wot I Think']
# 2022-11-14
# ['Indie', 'Management', 'Monkey Moon', 'Raw Fury', 'Story Rich', 'Wot I Think']
# 2022-11-14
# ['Management', 'Ravenscourt Games', 'Strategy', 'Vile Monarch', 'Wot I Think']
# 2022-11-11
# ['Anime', 'Fantasy', 'RPG', 'Square Enix', 'Wot I Think']
# 2022-11-10
# ['RPG', 'Strategy', 'Wot I Think']
# 2022-11-09
# ['Indie', 'Max Inferno', 'Puzzle', 'Secret Mode', 'Simulation', 'Wot I Think']
# 2022-11-08
# ['ARTE France', 'Baptiste Portefaix', 'Florian Veltman', 'Indie', 'Indiescovery', 'Puzzle', 'Wot I Think']
# 2022-11-07
# ['Activision Blizzard', 'Infinity Ward', 'Shooter', 'Wot I Think']
# 2022-11-04
# ['Action Adventure', 'Fantasy', 'poncle', 'Roguelike', 'Wot I Think']
# 2022-11-03
# ['Brass Token', 'Horror', 'Indie', 'Indiescovery', 'Prime Matter', 'Wot I Think']
# 2022-11-03
# ['Action Adventure', 'Humble Games', 'Indie', 'Indiescovery', 'Metroidvania', 'Old Moon', 'Wot I Think']
# 2022-11-02
# ['Bestest Bests', 'Horror', 'Humble Games', 'rose-engine', 'Survival & Crafting', 'Wot I Think']
# 2022-11-01
# ['RPG', 'Strategy', 'TaleWorlds', 'Wot I Think']
# 2022-10-31
# ['Brianna Lei', 'Comedy', 'Visual Novel & Dating', 'Wot I Think']
# 2022-10-27
# ['Bestest Bests', 'Horror', 'Indie', 'Indiescovery', 'Santa Ragione', 'Wot I Think']
# 2022-10-27
# ['Comedy', 'Grace Bruxner', 'Indie', 'superhot presents', 'Wot I Think']
# 2022-10-26
# ['Activision Blizzard', 'Infinity Ward', 'Shooter', 'Wot I Think']
# 2022-10-24
# ['Historical', 'Paradox Development Studio', 'Paradox Interactive', 'Simulation', 'Strategy', 'Wot I Think']
# 2022-10-20
# ['Action Adventure', 'Open World', 'RPG', 'Warner Bros. Games', 'Warner Bros. Games Montreal', 'Wot I Think']
# 2022-10-20
# ['2K', 'Blockbuster', 'Gearbox Software', 'Story Rich', 'Wot I Think']
# 2022-10-19
# ['Action Adventure', 'Asobo Studio', 'Focus Home Interactive', 'Horror', 'Puzzle', 'Stealth', 'Wot I Think']
# 2022-10-14
# ['Ebb Software', 'Horror', 'Indie', 'Indiescovery', 'Kepler Interactive', 'Wot I Think']
# 2022-10-13
# ['Color Gray Games', 'Indie', 'Indiescovery', 'Playstack', 'Puzzle', 'Story Rich', 'Wot I Think']
# 2022-10-12
# ['3D Realms', 'Horror', 'Indie', 'Shooter']
# 2022-10-11
# ['early access', 'Humble Games', 'Indie', 'Indiescovery', 'Sandbox', 'Simulation', 'Stairway Games', 'Wot I Think']
# 2022-10-05
# ['early access', 'Krafton', 'Strategy', 'Unknown Worlds', 'Wot I Think']
# 2022-10-04
# ['Blizzard', 'Blockbuster', 'Free-to-play', 'Shooter', 'Wot I Think']
# 2022-09-28
# ['Cloak And Dagger Games', 'Horror', 'Indie', 'Indiescovery', 'Point and Click', 'Wadjet Eye Games', 'Wot I Think']
# 2022-09-27
# ['Bippinbits', 'Indie', 'Management', 'Raw Fury', 'Roguelike', 'Science Fiction', 'Wot I Think']
# 2022-09-27
# ['Draw distance', 'Stealth', 'Wot I Think']
# 2022-09-27
# ['Obsidian Entertainment', 'Survival & Crafting', 'Wot I Think', 'Xbox Game Studios']
# 2022-09-22
# ['Ghost Ship Games', 'Indie', 'Simulation', 'Story Rich', 'Wot I Think']
# 2022-09-22
# ['JRPG', 'Lancarse', 'Strategy', 'Wot I Think']
# 2022-09-21
# ['Hiding Spot', 'Indie', 'Indiescovery', 'Story Rich']
# 2022-09-21
# ['Indie', 'Indiescovery', 'Shooter', 'Sorath']
# 2022-09-19
# ['Blockbuster', 'Devolver Digital', 'Indie', 'Indiescovery', 'Point and Click', 'Terrible Toybox', 'Wot I Think']
# 2022-09-16
# ['Fantasy', 'Indie', 'Management', 'Simulation', 'Strategy', 'Stray Fawn Studio', 'Survival & Crafting', 'Whisper Games', 'Wot I Think']
# 2022-09-15
# ['Alkemi', 'Card Games', 'Dear Villagers', 'Indie', 'Indiescovery', 'Story Rich', 'Strategy', 'Wot I Think']
# 2022-09-15
# ['Action Adventure', 'Disney', 'GameLoft', 'Kids & Family', 'Simulation', 'Wot I Think']
# 2022-09-13
# ['Funcom', 'Rhythm', 'Shooter', 'The Outsiders', 'Wot I Think']
# 2022-09-12
# ['BKOM Studios', 'Indie', 'Indiescovery', 'Point and Click', 'Puzzle', 'RPG', 'Team17', 'Wot I Think']
# 2022-09-09
# ['Action Adventure', 'Bestest Bests', 'Cosmo D', 'Cosmo D Studios', 'Demo', 'Indie', 'Indiescovery', 'Mac', 'PC', 'Point and Click', 'RPG', 'Wot I Think']
# 2022-09-08
# ['Action Adventure', 'Crema', 'Humble Games', 'MMO', 'RPG', 'Wot I Think']
# 2022-09-08
# ['Action Adventure', 'Hypetrain Digital', 'Indie', 'Indiescovery', 'JRPG', 'So Romantic', 'Wot I Think']
# 2022-09-08
# ['Assemble Entertainment', 'Fantasy', 'Indie', 'Moral Anxiety Studio', 'Visual Novel & Dating', 'Wot I Think']
# 2022-09-07
# ['Action Adventure', 'Indie', 'Nacon', 'RPG', 'Spiders', 'Wot I Think']
# 2022-09-06
# ['Afterburn', 'Indie', 'Indiescovery', 'Puzzle', 'Wot I Think']
# 2022-08-30
# ['Card Games', 'Critical Reflex', 'Fantasy', 'Indie', 'Johnbell', 'Roguelike', 'Strategy', 'Wot I Think']
# 2022-08-30
# ['Half Mermaid', 'Indie', 'Sam Barlow', 'Story Rich', 'Wot I Think']
# 2022-08-26
# ['Indie', 'Indiescovery', 'PC', 'Shooter', 'Sports']
# 2022-08-24
# ['Action Adventure', 'Indie', 'Platformer', 'Splashteam', 'tinyBuild', 'Wot I Think']
# 2022-08-22
# ['Blockbuster', 'Deep Silver', 'Open World', 'Shooter', 'Volition', 'Wot I Think']
# 2022-08-19
# ['Arcade', 'Chuhai Labs', 'Indie', 'Platformer', 'Sports', 'Thunderful Publishing', 'Wot I Think']
# 2022-08-17
# ['Indie', 'Story Rich', 'Visual Novel & Dating', 'Wot I Think']
# 2022-08-10
# ['Action Adventure', 'Blockbuster', 'Insomniac Games', 'Nixxes Software B.V.', 'Sony Interactive Entertainment', 'Wot I Think']
# 2022-08-10
# ['Action Adventure', 'Bestest Bests', 'Devolver Digital', 'Management', 'Massive Monster', 'Roguelike', 'Wot I Think']
# 2022-08-10
# ['Fantasy', 'Happy Juice Games', 'Indie', 'Joystick Ventures', 'Kids & Family', 'Point and Click', 'Puzzle', 'Wot I Think']
# 2022-08-09
# ['11 Bit Studios', 'Indie', 'Indiescovery', 'Point and Click', 'State of Play', 'Story Rich', 'Wot I Think']
# 2022-08-08
# ['Hugecalf Studios', 'Racing', 'Secret Mode', 'Sports', 'Steam', 'Wot I Think']
# 2022-08-04
# ['Action Adventure', 'Good Shepard Entertainment', 'Ice Code Games', 'RPG', 'Strategy', 'Wot I Think']
# 2022-08-04
# ['Management', 'Sega', 'Simulation', 'Two Point Studios', 'Wot I Think']
# 2022-07-28
# ['Armor Games Studios', 'Gummy Cat', 'Indie', 'Management', 'Wot I Think']
# 2022-07-28
# ['Cave Monsters', 'Comedy', 'Point and Click', 'Puzzle', 'Wings', 'Wot I Think']
# 2022-07-20
# ['Hooded Horse', 'MinMax Games', 'Simulation', 'Strategy', 'Wot I Think']
# 2022-07-19
# ['Action Adventure', 'Handy Games', 'Herobeat Studios', 'Indie', 'Indiescovery', 'Survival & Crafting', 'Wot I Think']
# 2022-07-18
# ['Action Adventure', 'Annapurna Interactive', 'Bestest Bests', 'BlueTwelve Studio', 'Science Fiction', 'Wot I Think']
# 2022-07-18
# ['Interior Night', 'Point and Click', 'Story Rich', 'Wot I Think', 'Xbox Game Studios']
# 2022-07-13
# ['Card Games', 'CD Projekt RED', 'Fantasy', 'Wot I Think']
# 2022-07-13
# ['Coin Crew Games', 'iam8bit', 'Point and Click', 'Puzzle', 'Skybound', 'Wot I Think']
# 2022-07-12
# ['Half Past Yellow', 'Indie', 'Indiescovery', 'Merge Games', 'Puzzle', 'Wot I Think']
# 2022-07-12
# ['FuturLab', 'Simulation', 'Square Enix', 'Wot I Think']
# 2022-07-08
# ['Bloodious Games', 'Horror', 'Indie', 'Indiescovery', 'Wot I Think']
# 2022-07-06
# ['Horror', 'Indie', 'Modern Wolf', 'Sandbox', 'Story Rich', 'Strange Scaffold', 'Wot I Think']
# 2022-06-30
# ['Free-to-play', 'Indie', 'MMO', 'Sandbox', 'Simulation', 'StikiPixels', 'Wot I Think']
# 2022-06-29
# ['Action Adventure', 'Blockbuster', 'Capcom', 'Fantasy', 'Hack & Slash', 'RPG']
# 2022-06-23
# ['Blockbuster', 'DLC', 'EA', 'Maxis', 'Simulation']
# 2022-06-21
# ['Angel Matrix', 'Anime', 'Annapurna Interactive', 'Bestest Bests', 'Indie', 'Platformer', 'Shooter', 'Wot I Think']
# 2022-06-16
# ['Blockbuster', 'Indie', 'Slitherine', 'Strategy', 'The Artistocrats', 'Wot I Think']
# 2022-06-15
# ['Arcade', 'DotEmu', 'Tribute Games Inc.', 'Wot I Think']
# 2022-06-10
# ['2K Games', 'Blockbuster', 'Horror', 'Story Rich', 'Supermassive Games', 'Wot I Think']
# 2022-06-09
# ['Indie', 'Indiescovery', 'Steam', 'Story Rich', 'Stunlock Studios', 'Survival & Crafting', 'Wot I Think']
# 2022-06-07
# ['Card Games', 'Devolver Digital', 'Indie', 'Indiescovery', 'Nerial', 'Puzzle', 'Story Rich', 'Wot I Think']
# 2022-06-01
# ['Fireshine Games', 'Indie', 'Indiescovery', 'Puzzle', 'Spiral Circus', 'Wot I Think']
# 2022-05-30
# ['Blackbird Interactive', 'early access', 'Prime Matter', 'Strategy', 'Wot I Think']
# 2022-05-27
# ['Bestest Bests', 'Blackbird Interactive', 'Focus Entertainment', 'Indie', 'Indiescovery', 'Simulation', 'Wot I Think']
# 2022-05-26
# ['Bestest Bests', 'Big Sugar Games', 'Indie', 'Ludomotion', 'Roguelike', 'Wot I Think']
# 2022-05-25
# ['Action Adventure', 'Shooter', 'Stealth', 'Wot I Think']
# 2022-05-23
# ['Indie', 'Indiescovery', 'Rose City Games', 'Strategy', 'Wot I Think']
# 2022-05-23
# ['early access', 'Indie', 'Pathea Games', 'Sandbox', 'Simulation', 'Wot I Think']
# 2022-05-18
# ['Cosmonaut Studios', 'Indie', 'Indiescovery', 'Puzzle', 'Secret Mode', 'Story Rich', 'Wot I Think']
# 2022-05-18
# ['Big Bad Wolf', 'Nacon', 'Puzzle', 'Story Rich', 'Wot I Think']
# 2022-05-18
# ['Broken Rules', 'Educational', 'Indie', 'Kids & Family', 'Wot I Think']
# 2022-05-11
# ['Coffee Stain Publishing', 'early access', 'Indiescovery', 'Lavapotion', 'RPG', 'Strategy', 'Wot I Think']
# 2022-05-11
# ['Carry Castle', 'Roguelike', 'Thunderful', 'Wot I Think']
# 2022-05-10
# ['505 Games', 'Action Adventure', 'Hack & Slash', 'Indie', 'JRPG', 'Natsume Atari', 'RPG', 'Wot I Think']
# 2022-05-09
# ['Blazing Bit Games', 'Shooter', 'Wot I Think']
# 2022-05-09
# ['Action Adventure', 'Indie', 'Indiescovery', 'RPG', 'Ska Studios', 'Wot I Think']
# 2022-05-05
# ['Action Adventure', 'Devolver Digital', 'Flying Wild Hog', 'Leonard Menchiari', 'Wot I Think']
# 2022-05-04
# ['Indie', 'Indiescovery', 'Joystick Ventures', 'Puzzle', 'Rendlike', 'Wot I Think']
# 2022-05-04
# ['Bestest Bests', 'Complex Games', 'Fantasy', 'Frontier Foundry', 'Strategy', 'Wot I Think']
# 2022-05-03
# ['Fellow Traveller', 'Indie', 'Indiescovery', 'Jump Over the Age', 'RPG', 'Wot I Think']
# 2022-04-28
# ['Cellar Door Games', 'Roguelike', 'Wot I Think']
# 2022-04-28
# ['Bestest Bests', 'Indie', 'Indiescovery', 'Puzzle', 'Strategy', 'Toukana Interactive', 'Wot I Think']
# 2022-04-26
# ['Curious Panda Games', 'Humble Games', 'Indie', 'Indiescovery', 'RPG', 'Strategy', 'Wot I Think']
# 2022-04-25
# ['Blockbuster', 'Indie', 'Shiro Games', 'Strategy', 'Wot I Think']
# 2022-04-22
# ['Fellow Traveller', 'Indie', 'Indiescovery', 'Silverstring Media', 'Wot I Think']
# 2022-04-21
# ['Apogee Entertainment', 'Bestest Bests', 'Indie', 'Shooter', 'Trigger Happy Interactive', 'Wot I Think']
# 2022-04-12
# ['B.I.O.T.A.', 'Indie', 'Indiescovery', 'Metroidvania', 'Retrovibe', 'Small Bros', 'Wot I Think']
# 2022-04-07
# ['General Interactive Co.', 'Humble Games', 'Indie', 'Indiescovery', 'Point and Click', 'Puzzle', 'Whisper Games', 'Wot I Think']
# 2022-04-06
# ['Action Adventure', 'TT Games', 'Warner Bros. Games', 'Wot I Think']
# 2022-04-01
# ['2K Games', 'Action Adventure', 'Blockbuster', 'Gearbox Software', 'RPG', 'Shooter', 'Wot I Think']
# 2022-03-31
# ['early access', 'Indie', 'Simulation', 'Strategy', 'The Knights Of Unity', 'Wield Interactive', 'Wot I Think']
# 2022-03-31
# ['Action Adventure', 'Bestest Bests', 'Devolver Digital', 'Horror', 'Indie', 'RPG', 'Sandbox', 'Stealth', 'Story Rich', 'WolfEye Studios', 'Wot I Think']
# 2022-03-29
# ['Fireshine Games', 'Four Circle Interactive', 'Indie', 'RPG', 'Sandbox', 'Sold Out', 'Stealth', 'Wot I Think']
# 2022-03-28
# ['Bestest Bests', 'Indie', 'Indiescovery', 'Patrick Traynor', 'Puzzle', 'Wot I Think']
# 2022-03-25
# ['Code Force', 'Sandbox', 'Simulation', 'Slitherine', 'Strategy', 'Wot I Think']
# 2022-03-21
# ['Blockbuster', 'Indie', 'Indiescovery', 'Sports', 'Wot I Think']
# 2022-03-21
# ['Action Adventure', 'Bethesda Softworks', 'Blockbuster', 'Horror', 'Open World', 'Tango Gameworks', 'Wot I Think']
# 2022-03-16
# ['Action Adventure', 'Andrew Shouldice', 'Finji', 'Hack & Slash', 'Indie', 'Wot I Think']
# 2022-03-10
# ['Code Force', 'Slitherine', 'Strategy', 'Wot I Think']
# 2022-03-09
# ['Action Adventure', 'Blockbuster', 'DLC', 'Ubisoft', 'Ubisoft Sofia', 'Wot I Think']
# 2022-03-04
# ['Hack & Slash', 'PlatinumGames', 'RPG', 'Square Enix', 'Wot I Think']
# 2022-02-28
# ['Action Adventure', 'Piranha Bytes', 'RPG', 'THQ Nordic', 'Wot I Think']
# 2022-02-28
# ['Benjamin Hauer', 'Goblinz Publishing', 'Indie', 'Indiescovery', 'Strategy', 'Wot I Think']
# 2022-02-28
# ['Action Adventure', 'Indie', 'Indiescovery', 'Secret Mode', 'Story Rich', 'The Chinese Room', 'Wot I Think']
# 2022-02-28
# ['Action Adventure', 'Devolver Digital', 'Flying Wild Hog', 'Hack & Slash', 'Shooter', 'Wot I Think']
# 2022-02-25
# ['early access', 'Indie', 'Indiescovery', 'MicroProse Software', 'Simulation', 'Wot I Think']
# 2022-02-25
# ['Blockbuster', 'Codemasters', 'EA', 'Racing', 'Wot I Think']
# 2022-02-24
# ['Horror', 'LKA', 'Wired Productions', 'Wot I Think']
# 2022-02-23
# ['Bandai Namco Entertainment', 'Bestest Bests', 'Blockbuster', 'FromSoftware', 'Open World', 'RPG', 'Wot I Think']
# 2022-02-21
# ['Bestest Bests', 'Frontier Foundry', 'Indie', 'Indiescovery', 'Okomotive', 'Story Rich', 'Wot I Think']
# 2022-02-14
# ['Blockbuster', 'Feral Interactive', 'Sega', 'Strategy', 'The Creative Assembly', 'Wot I Think']
# 2022-02-09
# ['Action Adventure', 'Indie', 'Indiescovery', 'Medallion Games', 'Platformer', 'Super Rare Games', 'Wot I Think']
# 2022-02-08
# ['Door 407', 'early access', 'Indie', 'Indiescovery', 'Sandbox', 'Strategy', 'Wot I Think']
# 2022-02-08
# ['Amazon Game Studios', 'MMO', 'RPG', 'Smilegate', 'Wot I Think']
# 2022-02-06
# ['Action Adventure', 'Bestest Bests', 'Indie', 'Sloclap', 'Wot I Think']
# 2022-02-03
# ['Action Adventure', 'Bestest Bests', 'Indie', 'Indiescovery', 'Platformer', 'Private Division', 'Roll7', 'Sports', 'Wot I Think']
# 2022-02-02
# ['Action Adventure', 'Blockbuster', 'Horror', 'Shooter', 'Story Rich', 'Techland', 'Wot I Think']
# 2022-02-01
# ['Gato Studio', 'Indie', 'Indiescovery', 'RPG', 'Wot I Think']
# 2022-01-31
# ['Arcade', 'early access', 'Indie', 'poncle', 'Roguelike', 'Wot I Think']
# 2022-01-28
# ['Action Adventure', 'ArticNet', 'Indie', 'Indiescovery', 'KEMCO', 'RPG', 'Sports', 'Wot I Think']
# 2022-01-28
# ['Gagex', 'Indie', 'Indiescovery', 'Point and Click', 'Story Rich', 'Wot I Think']
# 2022-01-27
# ['Akabaka', 'DreadXP', 'Horror', 'Indie', 'Indiescovery', 'Visual Novel & Dating', 'Wot I Think']
# 2022-01-27
# ['Action Adventure', 'Arcade', 'Arrowfist Games', 'Indie', 'Indiescovery', 'Roguelike', 'Wot I Think']
# 2022-01-25
# ['Gamera Game', 'Horror', 'Indie', 'Indiescovery', 'Puzzle', 'Shiying Studio', 'Wot I Think']
# 2022-01-20
# ['Iceberg Interactive', 'Indie', 'NotGames', 'Puzzle', 'Simulation', 'Story Rich', 'Wot I Think']
# 2022-01-20
# ['Action Adventure', 'Bad Viking', 'Bestest Bests', 'Iceberg Interactive', 'Indie', 'Puzzle', 'Wot I Think']
# 2022-01-20
# ['Arcade', 'DotEmu', 'Sports', 'Wot I Think']
# 2022-01-19
# ['Shooter', 'Ubisoft', 'Ubisoft Montreal', 'Wot I Think']
# 2022-01-18
# ['Logic Artists', 'PC', 'Simulation', 'Strategy', 'THQ Nordic', 'Wot I Think']
# 2022-01-18
# ['Action Adventure', 'DrinkBox Studios', 'Indie', 'RPG', 'Wot I Think']
# 2022-01-13
# ['Action Adventure', 'Han-Squirrel Studio', 'Indie', 'RPG', 'Strategy', 'Wot I Think', 'XD']
# 2022-01-12
# ['Action Adventure', 'Bestest Bests', 'Blockbuster', 'Santa Monica Studio', 'Sony', 'Wot I Think']
# 2022-01-10
# ['Action Adventure', 'Bestest Bests', 'Capcom', 'RPG', 'Wot I Think']
# 2021-12-24
# ['MMO', 'RPG', 'Wot I Think']
# 2021-12-22
# ['Action Adventure', 'Indie', 'microids', 'Pendulo Studios', 'Wot I Think']
# 2021-12-16
# ['Bestest Bests', 'RPG', 'Wot I Think']
# 2021-12-16
# ['Action Adventure', 'Image & Form', 'Image & Form Games', 'Platformer', 'Thunderful Publishing', 'Wot I Think']
# 2021-12-13
# ['Ground Shatter', 'Indie', 'Indiescovery', 'Mode 7 Games', 'Wot I Think']
# 2021-12-13
# ['Indie', 'Mixtvision', 'Thunderful Games', 'Wot I Think']
# 2021-12-10
# ['Blockbuster', 'Indie', 'RocketWerkz', 'Wot I Think']
# 2021-12-10
# ['Alientrap', 'Bestest Bests', 'Indie', 'Indiescovery', 'Puzzle', 'RPG', 'Whispergames', 'Whitethorn Digital', 'Wot I Think']
# 2021-12-09
# ['MMO', 'RPG', 'Wot I Think']
# 2021-12-06
# ['Modern Wolf', 'RPG', 'Whalenought Studios', 'Wot I Think']
# 2021-12-06
# ['343 Industries', 'Blockbuster', 'Shooter', 'Wot I Think', 'Xbox Game Studios']
# 2021-12-03
# ['Wot I Think']
# 2021-12-01
# ['Action Adventure', 'Annapurna Interactive', 'Heart Machine', 'Wot I Think']
# 2021-11-30
# ['early access', 'RPG', 'Shiro Games', 'Strategy', 'Wot I Think']
# 2021-11-29
# ['Action Adventure', 'Alawar Premium', 'Indie', 'Indiescovery', 'Platformer', 'Story Rich']
# 2021-11-25
# ['Indie', 'Indiescovery', 'No More Robots', 'Simulation', 'Springloaded', 'Wot I Think']
# 2021-11-23
# ['Exbleative', 'Indie', 'Wot I Think']
# 2021-11-19
# ['Blockbuster', 'Dice', 'Electronic Arts', 'Shooter', 'Wot I Think']
# 2021-11-18
# ['Action Adventure', 'Indie', 'Indiescovery', 'Laughing Machines', 'RPG', 'tinyBuild', 'Wot I Think']
# 2021-11-18
# ['Application Systems Heidelberg', 'Indie', 'Puzzle', 'Wot I Think']
# 2021-11-17
# ['Activision', 'Beenox', 'Shooter', 'Sledgehammer Games']
# 2021-11-16
# ['Sega', 'Sports Interactive', 'Strategy', 'Wot I Think']
# 2021-11-16
# ['Optillusion', 'Puzzle', 'Wot I Think', 'XD']
# 2021-11-15
# ['Action Adventure', 'Frogwares', 'Puzzle', 'Wot I Think']
# 2021-11-12
# ['Blockbuster', 'Frontier Developments', 'Strategy', 'Wot I Think']
# 2021-11-11
# ['Action Adventure', 'FYQD Personal Studio', 'playism', 'Shooter', 'Wot I Think']
# 2021-11-11
# ['Blockbuster', 'Dice', 'Electronic Arts', 'Shooter']
# 2021-11-11
# ['Action Adventure', 'Indie', 'Indiescovery', 'Puzzle', 'Sold Out', 'White Paper Games']
# 2021-11-09
# ['Bestest Bests', 'Humble Games', 'Indie', 'Indiescovery', 'Witch Beam', 'Wot I Think']
# 2021-11-09
# ['Activision', 'Beenox', 'Shooter', 'Sledgehammer Games']
# 2021-11-09
# ['Bestest Bests', 'Playground Games', 'Racing', 'Wot I Think', 'Xbox Game Studios']
# 2021-11-03
# ['Action Adventure', 'Fabraz', 'Indie', 'Platformer', 'Playtonic Friends', 'Wot I Think']
# 2021-11-03
# ['RPG', 'Wot I Think']
# 2021-11-02
# ['Sports', 'Ubisoft', 'Ubisoft Annecy', 'Wot I Think']
# 2021-11-02
# ['Action Adventure', 'Cococucumber', 'RPG', 'Wot I Think']
# 2021-11-01
# ['Red Hook Studios', 'RPG', 'Wot I Think']
# 2021-10-25
# ['Bunnyhug Games', 'Coatsink', 'Indie', 'RPG', 'Wot I Think']
# 2021-10-25
# ['Action Adventure', 'Blockbuster', 'Eidos Montreal', 'Marvel', 'Wot I Think']
# 2021-10-25
# ['Relic Entertainment', 'Strategy', 'Wot I Think', 'Xbox Game Studios']
# 2021-10-21
# ['Action Adventure', 'Bandai Namco Entertainment', 'Blockbuster', 'Horror', 'Supermassive Games', 'The Dark Pictures Anthology', 'Wot I Think']
# 2021-10-21
# ['DANGEN Entertainment', 'Indie', 'Roguelike', 'Wot I Think']
# 2021-10-20
# ['Asmodee Digital', 'Bestest Bests', 'Flaming Fowl Studios', 'RPG', 'Wot I Think']
# 2021-10-19
# ['Brainwash Gang', 'Digerati', 'Story Rich', 'Wot I Think']
# 2021-10-19
# ['Action Adventure', 'RPG', 'Strategy', 'Wot I Think']
# 2021-10-18
# ['Humble', 'Indie', 'Nullpointer Games', 'Shooter', 'Wot I Think']
# 2021-10-18
# ['Bestest Bests', 'Daniel Mullins Games', 'Devolver Digital', 'Horror', 'Indie', 'Strategy', 'Wot I Think']
# 2021-10-14
# ['Bestest Bests', 'Indie', 'NamaTakahashi', 'Platformer', 'Puzzle', 'Wot I Think']
# 2021-10-14
# ['Action Adventure', 'playism', 'RPG', 'Simulation', 'White Owls', 'Wot I Think']
# 2021-10-13
# ['Action Adventure', 'CyberConnect2', 'Fighting', 'Sega', 'Wot I Think']
# 2021-10-08
# ['Freebird Games', 'Indie', 'Indiescovery', 'Wot I Think']
# 2021-10-08
# ['Amazon Games', 'Blockbuster', 'MMO', 'Wot I Think']
# 2021-10-06
# ['Blockbuster', 'Shooter', 'Ubisoft', 'Wot I Think']
# 2021-10-04
# ['Frontier Foundry', 'Ratloop Games Canada', 'Shooter', 'Wot I Think']
# 2021-10-04
# ['Action Adventure', 'Epic Games', 'Horror', 'Remedy Entertainment', 'Wot I Think']
# 2021-10-04
# ['Action Adventure', 'Indie', 'Pine Scented Software', 'Superbrothers', 'Wot I Think']
# 2021-09-30
# ['ACE Team', 'Indie', 'Puzzle', 'Thunderful Publishing', 'Wot I Think']
# 2021-09-30
# ['Indie', 'Indiescovery', 'Leikir Studio', 'Nacon', 'Strategy', 'Wot I Think']
# 2021-09-27
# ['Artisan Studio', 'Dear Villagers', 'RPG', 'Wot I Think']
# 2021-09-22
# ['Action Adventure', 'Indie', 'Raw Fury', 'Shedworks', 'Wot I Think']
# 2021-09-21
# ['Action Adventure', 'Bestest Bests', 'Ember Lab', 'Indie', 'Indiescovery', 'Wot I Think']
# 2021-09-17
# ['Action Adventure', 'CI Games', 'Indie', 'Indiescovery', 'Odd Bug Games', 'United Label', 'Wot I Think']
# 2021-09-16
# ['Anshar Studios', 'Indie', 'RPG', 'Wot I Think']
# 2021-09-16
# ['Glass Bottom Games', 'Sports', 'Wot I Think']
# 2021-09-16
# ['Indie', 'Indiescovery', 'Juggler Games', 'Klabater', 'Strategy', 'Wot I Think']
# 2021-09-15
# ['Lince Works', 'Stealth', 'Wot I Think']
# 2021-09-15
# ['Action Adventure', 'Bossa Studios', 'Curve Digital', 'Platformer', 'Wot I Think']
# 2021-09-14
# ['Action Adventure', 'Chucklefish', 'Indie', 'Pixpil', 'RPG', 'Wot I Think']
# 2021-09-13
# ['Indie', 'Indiescovery', 'Something We Made', 'Wot I Think']
# 2021-09-13
# ['Arkane Lyon', 'Bestest Bests', 'Bethesda Softworks', 'Blockbuster', 'Shooter', 'Wot I Think']
# 2021-09-10
# ['Action Adventure', 'Blockbuster', 'EA Originals', 'Electronic Arts', 'Indie', 'Strategy', 'Thunderful Games', 'Wot I Think', 'Zoink!']
# 2021-09-09
# ['Indie', 'Maple Whispering Limited', 'Strategy', 'Wot I Think']
# 2021-09-09
# ['1047 Games', 'Bestest Bests', 'Shooter', 'Wot I Think']
# 2021-09-09
# ['Indie', 'Noio', 'Puzzle', 'Wot I Think']
# 2021-09-08
# ['Blockbuster', 'Deck Nine Games', 'Story Rich', 'Wot I Think']
# 2021-09-08
# ['Annapurna Interactive', 'Beethoven & Dinosaur', 'Blockbuster', 'Indie', 'Platformer', 'Wot I Think']
# 2021-09-08
# ['Bandai Namco Entertainment', 'BANDAI NAMCO Studios', 'RPG', 'Wot I Think']
# 2021-09-02
# ['Demagog Studio', 'Untold Tales', 'Wot I Think']
# 2021-09-02
# ['Action Adventure', 'Crim', 'Wot I Think']
# 2021-08-31
# ['Action Adventure', 'Indie', 'Indiescovery', 'Mighty Yell', 'Skybound Tabletop', 'Wot I Think']
# 2021-08-31
# ['Indie', 'Indiescovery', 'Puzzle', 'Sold Out', 'Stonewheat & Sons', 'Wot I Think']
# 2021-08-23
# ['1C Entertainment', 'Blockbuster', 'Indie', 'Strategy', 'Wot I Think']
# 2021-08-23
# ['Bestest Bests', 'Blockbuster', 'Double Fine Productions', 'Platformer', 'Wot I Think', 'Xbox Game Studios']
# 2021-08-23
# ['PM Studios, inc.', 'skrollcat-studio', 'Wot I Think']
# 2021-08-19
# ['Action Adventure', 'Dear Villagers', 'Phigames']
# 2021-08-18
# ['Annapurna Interactive', 'Indie', 'Indiescovery', 'Luis Antonio', 'Wot I Think']
# 2021-08-16
# ['Indie', 'Picogram', 'Rose City Games', 'RPG', 'Wot I Think']
# 2021-08-16
# ['AMPLITUDE Studios', 'Reviews', 'Sega', 'Strategy', 'Wot I Think']
# 2021-08-16
# ['24 Entertainment', 'Action Adventure', 'Netease Games', 'Wot I Think']
# 2021-08-16
# ['DigixArt Studio', 'Indie', 'Indiescovery', 'Wot I Think']
# 2021-08-12
# ['Action Adventure', 'Indie', 'Merge Games', 'Shooter', 'Wot I Think']
# 2021-08-12
# ['Action Adventure', 'Indie', 'Indiescovery', 'Kitfox Games', 'Wot I Think']
# 2021-08-11
# ['Action Adventure', 'Indie', 'Indiescovery', 'Platformer', 'Thomas Happ Games', 'Wot I Think']
# 2021-08-11
# ['Blockbuster', 'Ubisoft', 'Ubisoft Montreal', 'Wot I Think']
# 2021-08-09
# ['Geometa', 'MicroProse Software', 'Strategy', 'Wot I Think']
# 2021-08-09
# ['Action Adventure', 'Indie', 'Subliminal']
# 2021-08-05
# ['Hypetrain Digital', 'Indie', 'Indiescovery', 'Morteshka', 'Wot I Think']
# 2021-08-05
# ['Crafting Legends', 'early access', 'Indie', 'Indiescovery', 'Wot I Think']
# 2021-07-29
# ['Blockbuster', 'EA', 'Electronic Arts', 'Maxis', 'Simulation', 'Wot I Think']
# 2021-07-29
# ['Action Adventure', 'Curve Digital', 'Neon Giant', 'RPG', 'Wot I Think']
# 2021-07-27
# ['RPG', 'The Farm 51', 'Wot I Think']
# 2021-07-27
# ['Dear Villagers', 'Indie', 'Indiescovery', 'Modern Storyteller', 'Puzzle', 'Story Rich', 'Wot I Think']
# 2021-07-26
# ['Konstantin Koshutin', 'MicroProse Software', 'Strategy', 'Wot I Think']
# 2021-07-26
# ['Ace Attorney', 'Capcom', 'Wot I Think']
# 2021-07-21
# ['Annapurna Interactive', 'Indie', 'Variable State', 'Wot I Think']
# 2021-07-20
# ['Acid Nerve', 'Devolver Digital', 'Indie', 'Indiescovery', 'Wot I Think']
# 2021-07-19
# ['Blockbuster', 'Dreams Uncorporated', 'Indie', 'Modus Games', 'RPG', 'SYCK', 'Wot I Think']
# 2021-07-19
# ['Bestest Bests', 'Dinosaur Polo Club', 'Indie', 'Indiescovery', 'Simulation', 'Wot I Think']
# 2021-07-07
# ['Capcom', 'Wot I Think']
# 2021-07-01
# ['Bestest Bests', 'Finji', 'Greg Lobanov', 'Indie', 'Wot I Think']
# 2021-06-29
# ['Action Adventure', 'Goichi Suda', 'Grasshopper Manufacture', 'Marvelous', 'Wot I Think', 'XSEED']
# 2021-06-29
# ['Consumer Softproducts', 'Indie', 'Shooter', 'Wot I Think']
# 2021-06-23
# ['Bestest Bests', 'RPG', 'Strategy', 'Wot I Think']
# 2021-06-23
# ['Bandai Namco Entertainment', 'BANDAI NAMCO Studios', 'Wot I Think']
# 2021-06-17
# ['Bestest Bests', 'Indie', 'Indiescovery', 'Nifflas', 'Nifflas & Triple Topping', 'Triple Topping', 'Wot I Think']
# 2021-06-16
# ['Action Adventure', 'Blockbuster', 'Torn Banner Studios', 'Tripwire Interactive', 'Wot I Think']
# 2021-06-14
# ['Bestest Bests', 'Indie', 'Indiescovery', 'Puzzle', 'Studio Fizbin', 'Wot I Think']
# 2021-06-08
# ['Beetlewing', 'Bestest Bests', 'Indie', 'Indiescovery', 'Puzzle', 'Strategy', 'Wot I Think']
# 2021-06-08
# ['EggNut', 'Indie', 'Raw Fury', 'Wot I Think']
# 2021-06-07
# ['ByteRockers Games', 'Wot I Think']
# 2021-06-07
# ['early access', 'Indie', 'Toukana Interactive', 'Wot I Think']
# 2021-06-04
# ['AMC Games', 'Indie', 'Thunkd', 'Wot I Think']
# 2021-06-02
# ['Indie', 'Inkle Studios', 'Puzzle', 'Wot I Think']
# 2021-05-28
# ['Action Adventure', 'Indie', 'Puzzle', 'Wadjet Eye Games', 'Wormwood Studios', 'Wot I Think']
# 2021-05-28
# ['Frontier Developments', 'Wot I Think']
# 2021-05-24
# ['Action Adventure', 'Experiment 101', 'RPG', 'THQ Nordic', 'Wot I Think']
# 2021-05-18
# ['Atlus', 'Feature', 'Reviews', 'Sega', 'Wot I Think']
# 2021-05-13
# ['Unknown Worlds Entertainment', 'Wot I Think']
# 2021-05-05
# ['Capcom', 'Feature', 'Reviews', 'Wot I Think']
# 2021-04-27
# ['Feature', 'Reviews', 'Toylogic', 'Wot I Think']
# 2021-04-22
# ['Feature', 'Graffiti Games', 'Reviews', 'Snoozy Kazoo']
# 2021-04-12
# ['Feature', 'People Can Fly', 'Reviews', 'Wot I Think']
# 2021-03-29
# ['Feature', 'Rebellion Developments', 'Reviews', 'Wot I Think']
# 2021-03-26
# ['Bestest Bests', 'Feature', 'Reviews', 'Ryu Ga Gotoku Studio', 'Wot I Think']
# 2021-03-26
# ['Feature', 'Kalypso Media', 'Realmforge Studios', 'Reviews', 'Wot I Think']
# 2021-03-26
# ['Feature', 'Fellow Traveller', 'Feral Cat Den', 'Reviews', 'Wot I Think']
# 2021-03-24
# ['EA Originals', 'Electronic Arts', 'Feature', 'Hazelight Studios', 'Reviews', 'Wot I Think']
# 2021-03-19
# ['Devolver Digital', 'Feature', 'Four Quarters', 'Reviews']
# 2021-03-08
# ['Annapurna Interactive', 'Feature', 'Graceful Decay', 'Indiescovery', 'Reviews', 'Wot I Think']
# 2021-02-23
# ['Atlus', 'Feature', 'Reviews', 'Sega', 'Wot I Think']
# 2021-02-12
# ['Cassel Games', 'Feature', 'Reviews', 'Wot I Think']
# 2021-02-10
# ['AGM Playism', 'Feature', 'Reviews', 'Wot I Think']
# 2021-02-09
# ['Assemble Entertainment', 'Chaosmonger Studio', 'Reviews', 'Wot I Think']
# 2021-02-09
# ['Bandai Namco Entertainment', 'Bestest Bests', 'Feature', 'Reviews', 'Tarsier Studios', 'Wot I Think']
# 2021-02-08
# ['Feature', 'Koei Tecmo', 'Koei Tecmo Games', 'Reviews', 'Team Ninja', 'Wot I Think']
# 2021-02-03
# ['Gust', 'Koei Tecmo Games', 'Reviews', 'Wot I Think']
# 2021-01-28
# ['Bloober Team', 'Bloober Team S.A.', 'Feature', 'Reviews']
# 2021-01-27
# ['Maschinen-Mensch', 'Reviews', 'Strategy', 'Thunderful Publishing', 'Wot I Think']
# 2021-01-19
# ['Action Adventure', 'Feature', 'IO Interactive', 'Reviews', 'Stealth', 'Wot I Think']
# 2020-12-16
# ['Blockbuster', 'CD Projekt RED', 'Feature', 'Reviews', 'RPG', 'Wot I Think']
# 2020-12-08
# ['2 Ton Studios', 'Big Sugar', 'Feature', 'Indie', 'Reviews', 'Wot I Think']
# 2020-12-07
# ['Action Adventure', 'Feature', 'Gunfire Games', 'Reviews', 'RPG', 'THQ Nordic', 'Wot I Think']
# 2020-12-03
# ['Action Adventure', 'Feature', 'Indie', 'Reviews', 'Story Rich', 'The game bakers', 'Wot I Think']
# 2020-11-30
# ['Action Adventure', 'Blockbuster', 'Feature', 'Reviews', 'Ubisoft Quebec', 'Wot I Think']
# 2020-11-30
# ['Feature', 'Paradox Interactive', 'Reviews', 'Romero Games', 'Strategy', 'Wot I Think']
# 2020-11-25
# ['Activision Blizzard', 'Blockbuster', 'Feature', 'Raven Software', 'Reviews', 'Shooter', 'Treyarch', 'Wot I Think']
# 2020-11-17
# ['Feature', 'Indie', 'Nova-box', 'Reviews', 'Story Rich', 'Wot I Think']
# 2020-11-16
# ['Action Adventure', 'Feature', 'Reviews', 'Wot I Think']
# 2020-11-16
# ['Action Adventure', 'Activision Blizzard', 'Blockbuster', 'Feature', 'Raven Software', 'Reviews', 'Shooter', 'Story Rich', 'Treyarch', 'Wot I Think']
# 2020-11-09
# ['Feature', 'Indie', 'Puzzle', 'Reviews', 'Wot I Think']
# 2020-11-09
# ['Action Adventure', 'Blockbuster', 'Feature', 'Reviews', 'Ubisoft', 'Ubisoft Montreal', 'Wot I Think']
# 2020-11-06
# ['Action Adventure', 'Bestest Bests', 'Feature', 'Reviews', 'RPG', 'Ryu Ga Gotoku Studio', 'Sega', 'Wot I Think']
# 2020-11-04
# ['Blockbuster', 'Feature', 'Indie', 'Reviews', 'Shooter', 'Simulation', 'Tuxedo Labs', 'Wot I Think']
# 2020-11-02
# ['Bandai Namco Entertainment', 'Feature', 'Horror', 'Reviews', 'Supermassive Games', 'Wot I Think']
# 2020-10-28
# ['Action Adventure', 'Blockbuster', 'Feature', 'Reviews', 'RPG', 'Simulation', 'Stealth', 'Ubisoft', 'Ubisoft Montreal', 'Wot I Think']
# 2020-10-27
# ['Action Adventure', 'Arcade', 'Dear Villagers', 'Feature', 'Flying Oak Games', 'Indie', 'Platformer', 'Reviews', 'Wot I Think']
# 2020-10-26
# ['505 Games', 'Action Adventure', 'All In! Games', 'Feature', 'One More Level', 'Reviews', 'Shooter', 'Wot I Think']
# 2020-10-22
# ['Action Adventure', 'Devolver Digital', 'Doseone', 'Feature', 'Indie', 'Jan Willem Nijman', 'Kitty Calis', 'Reviews', 'Terri Vellmann', 'Wot I Think']
# 2020-10-19
# ['Feature', 'Frictional Games', 'Horror', 'Indie', 'Reviews', 'Wot I Think']
# 2020-10-16
# ['Feature', 'Indie', 'Nolla Games', 'Reviews', 'Simulation', 'Wot I Think']
# 2020-10-16
# ['Feature', 'Indie', 'Reviews', 'Wot I Think']
# 2020-10-14
# ['Daedalic Entertainment', 'Feature', 'Reviews', 'Stealth', 'Strategy', 'Wot I Think']
# 2020-10-13
# ['Action Adventure', 'Echtra Games', 'Feature', 'perfect world', 'Reviews', 'RPG']
# 2020-10-13
# ['Curve Digital', 'Feature', 'Reviews', 'Runner Duck', 'Simulation', 'Strategy', 'Wot I Think']
# 2020-10-07
# ['Annapurna Interactive', 'Feature', 'Hollow Ponds', 'Indie', 'Puzzle', 'Reviews', 'Richard Hogg', 'Story Rich', 'Wot I Think']
# 2020-10-07
# ['Action Adventure', 'Blockbuster', 'Electronic Arts', 'Feature', 'Motive Studios', 'Reviews', 'Simulation', 'VR']
# 2020-10-06
# ['Action Adventure', 'early access', 'Feature', 'Larian Studios', 'Reviews', 'RPG', 'Strategy', 'Strategy: Turn-Based Strategy', 'Wot I Think']
# 2020-10-01
# ['Feature', 'Indie', 'Puzzle', 'Reviews', 'Story Rich']
# 2020-10-01
# ['Artefacts Studio', 'Dear Villagers', 'Feature', 'Reviews', 'Strategy', 'Wot I Think']
# 2020-09-29
# ['Action Adventure', 'Bestest Bests', 'Blitworks', 'Feature', 'Mossmouth', 'Platformer', 'Reviews', 'Wot I Think']
# 2020-09-22
# ['Crytek', 'Feature', 'Reviews', 'Saber Interactive', 'Shooter', 'Wot I Think']
# 2020-09-22
# ['Feature', 'Indie', 'Inkle Studios', 'Reviews', 'Story Rich', 'Strategy', 'Wot I Think']
# 2020-09-17
# ['Action Adventure', 'Bestest Bests', 'Feature', 'Reviews', 'Supergiant Games', 'Wot I Think']
# 2020-09-17
# ['Bestest Bests', 'Feature', 'Horror', 'Indie', 'Reviews', 'Shooter', 'Wot I Think', 'YCJY Games']
# 2020-09-17
# ['Deep Silver', 'Feature', 'KING Art', 'Reviews', 'Strategy', 'Wot I Think']
# 2020-09-16
# ['Draknek', 'Feature', 'Puzzle', 'Reviews', 'Wot I Think']
# 2020-09-11
# ['Feature', 'Indie', 'Massive Damage', 'Raw Fury', 'Reviews', 'RPG', 'Strategy', 'Wot I Think']
# 2020-09-09
# ['Feature', 'Fellow Traveller', 'Indie', 'Kaizen Game Works', 'Puzzle', 'Reviews', 'Story Rich', 'Wot I Think']
# 2020-09-01
# ['Blockbuster', 'DONTNOD Entertainment', 'Feature', 'Reviews', 'Story Rich', 'Wot I Think', 'Xbox Game Studios']
# 2020-08-31
# ['Feature', 'Paradox Development Studio', 'Paradox Interactive', 'Reviews', 'RPG', 'Strategy', 'Wot I Think']
# 2020-08-27
# ['Feature', 'inXile Entertainment', 'Reviews', 'RPG', 'Story Rich', 'Wot I Think']
# 2020-08-25
# ['Action Adventure', 'Feature', 'Metronomik', 'Reviews', 'Sold Out', 'Wot I Think']
# 2020-08-18
# ['Bestest Bests', 'Feature', 'Indie', 'Reviews', 'Story Rich', 'Thunder Lotus Games', 'Wot I Think']
# 2020-08-17
# ['Action Adventure', 'Cold Symmetry', 'Feature', 'Playstack', 'Reviews', 'RPG', 'Wot I Think']
# 2020-08-13
# ['Creative Assembly Sofia', 'Feature', 'Reviews', 'Sega', 'Strategy', 'The Creative Assembly', 'Wot I Think']
# 2020-08-07
# ['Action Adventure', 'Bestest Bests', 'Blockbuster', 'Guerrilla Games', 'Reviews', 'Sony', 'Wot I Think']
# 2020-07-30
# ['Action Adventure', 'Feature', 'nussoft', 'Reviews', 'Wot I Think']
# 2020-07-28
# ['Feature', 'Horror', 'Reviews', 'Wales Interactive', 'Wot I Think']
# 2020-07-28
# ['Devolver Digital', 'Feature', 'Horror', 'Indie', 'Phobia Game Studio', 'Reviews', 'Wot I Think']
# 2020-07-22
# ['Bestest Bests', 'Feature', 'Indie', 'Polygon Treehouse', 'Puzzle', 'Reviews', 'United Label', 'Wot I Think']
# 2020-07-21
# ['AGM Playism', 'Bestest Bests', 'Coconut Island Games', 'Feature', 'Indie', 'Reviews', 'Route 59', 'Story Rich', 'Wot I Think']
# 2020-07-06
# ['Feature', 'Indie', 'neowiz', 'Reviews', 'Strategy', 'Wot I Think']
# 2020-06-24
# ['E3 2020', 'early access', 'Feature', 'FJRD Interactive', 'Indie', 'Reviews', 'Simulation', 'Wot I Think']
# 2020-06-23
# ['Blackbird Interactive', 'Feature', 'Focus Home Interactive', 'Premature Evaluation', 'Puzzle', 'Reviews', 'Simulation', 'Steam']
# 2020-06-23
# ['Atlus', 'Feature', 'Reviews', 'RPG', 'Sega', 'Wot I Think']
# 2020-06-23
# ['Feature', 'Klei Entertainment', 'Reviews', 'Strategy', 'Wot I Think']
# 2020-06-19
# ['Feature', 'Private Division', 'Reviews', 'Shooter', 'Strategy', 'V1 Interactive', 'Wot I Think']
# 2020-06-16
# ['Action Adventure', 'Bad Yolk Games', 'Feature', 'Premature Evaluation', 'Puzzle', 'Reviews', 'Simulation', 'Steam', 'Team17']
# 2020-06-15
# ['E-Line Media', 'Feature', 'Reviews', 'Simulation', 'Wot I Think']
# 2020-06-12
# ['Bestest Bests', 'Feature', 'Mimimi Productions', 'Reviews', 'Stealth', 'Strategy', 'The Flare Path', 'THQ Nordic', 'Wot I Think']
# 2020-06-11
# ['Bugbyte', 'Feature', 'Indie', 'Premature Evaluation', 'Reviews', 'Science Fiction', 'Simulation', 'Steam']
# 2020-06-10
# ['Blockbuster', 'EA Maxis', 'Electronic Arts', 'expansion packs', 'Feature', 'Reviews', 'Simulation', 'Wot I Think']
# 2020-06-08
# ['Electronic Arts', 'Esports', 'Feature', 'Petroglyph', 'Reviews', 'Strategy', 'Wot I Think']
# 2020-06-08
# ['Action Adventure', 'early access', 'Feature', 'Puzzle', 'Reviews', 'Shooter', 'Simulation', 'Wot I Think']
# 2020-06-05
# ['Bestest Bests', 'Feature', 'Reviews', 'Shiny Shoe', 'Strategy', 'Wot I Think']
# 2020-06-04
# ['Feature', 'Nimble Giant Entertainment', 'Reviews', 'Shooter', 'Wot I Think']
# 2020-06-03
# ['early access', 'Feature', 'Mohawk Games', 'Premature Evaluation', 'Reviews', 'Simulation', 'Story Rich', 'Strategy']
# 2020-06-03
# ['Feature', 'Reviews', 'Riot Games', 'Shooter', 'Wot I Think']
# 2020-06-03
# ['Dry Cactus', 'Feature', 'Puzzle', 'Reviews', 'Simulation', 'Wot I Think']
# 2020-06-02
# ['Feature', 'Reviews', 'Simulation', 'Strategy', 'Stray Fawn Studio', 'Whispergames', 'Wot I Think']

# %%
print(f"There are {len(reviews_in_recent_years)} review articles published on RockPaperShotgun.com in the recent three and half years (1/6/2020 - 1/12/2023)")
# Out:
# There are 540 review articles published on RockPaperShotgun.com in the recent three and half years (1/6/2020 - 1/12/2023)

# %% [markdown]
# #### 3. Extract data (title, developer, label, brief, review, date) from each webpage
# - note that different webpages have different html formats for developer, brief, and body text (review), requiring different code to handle each variation
# - please refer to '1a_web_scrape_test_code.ipynb' for different formats (I've summarised 11 different formats in total; due to limited timeframe, other format or errors (if occurred) will be manually examined/fixed/removed after extrating all data)

# %%
# code used to extract each format is first tested in '1a_web_scrape_test_code.ipynb' 
# combine all the code together to extract everything at once

game_titles = []
developers = []
labels = []
briefs = []
reviews = []
dates = []

# iterate using enumerate - get both index and element
for i, element in enumerate(reviews_in_recent_years):
    response = requests.get(url=reviews_in_recent_years[i]['URL'])
    html_code = response.text
    soup = BeautifulSoup(html_code, "html.parser")

    # extract date - same for all webpages
    date = soup.find("time").get('datetime')[:10]
    dates.append(date)

    # extract game titles from url link - same for all webpages
    link_title = " ".join(element['URL'].replace("https://www.rockpapershotgun.com/", "").split("-")).title()
    cleaned_link_title = re.sub(r'Review.*', 'Review', link_title) # Use regex to remove everything after 'review'
    game_title = cleaned_link_title.replace(" Review", "").replace("Wot I Think ", "")
    game_titles.append(game_title)

    # extract topics provided at the end of review - same for all webpages
    topic = soup.select("#content_above > .page_content span.tagged_with_item.tagged_with_item--secondary a")
    label = []
    for item in topic:
        label.append(item.text)
    labels.append(label)

    info = soup.select("div.article_body_content li")

    if len(info) != 0: # info/brief is directly available for scraping (mostly)
        # extract developer info
        developer = info[0].text.replace("Developer:", "").replace("Developer:", "").replace("\n","")
        developers.append(developer)

        # try.. except.. reference code found in: https://www.programiz.com/python-programming/exception-handling
        try: 
            brief = str(soup.select(".article_body_content > :nth-child(1)"))
            pattern = re.compile(r'<strong>.+?</strong>(.+?)<ul>', re.DOTALL)
            text = re.search(pattern, brief).group(1).strip().replace("\r", "").replace("\n", "")
            # remove everything in <> and <> itself, if any
            brief_text = re.sub(r'<.*?>', '', text)
            if brief_text == "":
                brief_text = "n/a"

            print(f"index{i} is Type I, format 1 - {element['Title']}: {element['URL']}")

            # extract review
            body = soup.select("div.article_body_content p")
            body_text = ""
            for item in body:
                body_text += item.text

        except AttributeError:
            try: 
                brief = str(soup.select(".article_body_content > :nth-child(2)"))
                pattern = re.compile(r'<strong>.+?</strong>(.+?)<ul>', re.DOTALL)
                text = re.search(pattern, brief).group(1).strip().replace("\r", "").replace("\n", "")
                # remove everything in <> and <> itself, if any
                brief_text = re.sub(r'<.*?>', '', text)

                print(f"index{i} is Type I, format 2 - {element['Title']}: {element['URL']}")

                # extract review
                body = soup.select("div.article_body_content p")
                body_text = ""
                for item in body:
                    body_text += item.text

            except AttributeError:
                try:
                    brief = str(soup.select(".article_body_content > :nth-child(3)"))
                    pattern = re.compile(r'<strong>.+?</strong>(.+?)<ul>', re.DOTALL)
                    text = re.search(pattern, brief).group(1).strip().replace("\r", "").replace("\n", "")
                    # remove everything in <> and <> itself, if any
                    brief_text = re.sub(r'<.*?>', '', text)

                    print(f"index{i} is Type I, format 3 - {element['Title']}: {element['URL']}")

                    # extract review
                    body = soup.select("div.article_body_content p")
                    body_text = ""
                    for item in body:
                        body_text += item.text

                except AttributeError:
                    try: 
                        brief_text = soup.select(":nth-child(1) > em")[0].text

                        print(f"index{i} is Type I, format 4 - {element['Title']}: {element['URL']}")

                        # extract review
                        body = soup.select("div.article_body_content p")
                        body_text = ""
                        for item in body:
                            body_text += item.text

                    except IndexError:
                        try:
                            brief_text = soup.select(".article_body_content aside p")[0].text

                            print(f"index{i} is Type I, format 5 - {element['Title']}: {element['URL']}")

                            # extract review
                            body = (soup.select("div.article_body_content p"))[1:]
                            body_text = ""
                            for item in body:
                                body_text += item.text
                        
                        except IndexError:
                            brief_text = "n/a"

                            print(f"index{i} is Type II, format 2 - {element['Title']}: {element['URL']}")

                            # extract review
                            body = (soup.select("div.article_body_content p"))
                            body_text = ""
                            for item in body:
                                body_text += item.text             

    else: # info is not directly available for scraping or there is no info/brief at all 
        developer_tag = soup.find('strong', string='Developer:')
        if developer_tag is not None: # if developer_tag can be found - some or all info can be scrapped
            try:
                brief_str = str(soup.select(".article_body_content > :nth-child(2)"))
                pattern = re.compile(r'<strong>.*?</strong><br/>\s*(.*?)\s*<', re.DOTALL)
                brief_text = re.findall(pattern, brief_str)[0]      

                print(f"index{i} is Type I, format 6 - {element['Title']}: {element['URL']}")

                # extract review
                body = soup.select("div.article_body_content p")[2:]
                body_text = ""
                for item in body:
                    body_text += item.text

            except IndexError:
                brief_str = soup.select(".article_body_content > :nth-child(1)")[0].text
                
                if brief_str is None or brief_str == "": # probably is the img link with no brief, or simly extract an empty text
                    try:
                        brief = soup.select("em")[0].text
                        brief_text = brief

                        print(f"index{i} is Type I, format 8 - {element['Title']}: {element['URL']}")

                    except IndexError:
                        brief_text = "n/a"

                        print(f"index{i} is Type II, format 1 - {element['Title']}: {element['URL']}")

                    # extract review - iterate until find the body text
                    if "Release" not in soup.select("div.article_body_content p")[0].text and soup.select("div.article_body_content p")[0].text !="":
                        body = soup.select("div.article_body_content p")[0:]
                    elif "Release" not in soup.select("div.article_body_content p")[1].text and soup.select("div.article_body_content p")[0].text !="":
                        body = soup.select("div.article_body_content p")[1:] 
                    elif "Release" not in soup.select("div.article_body_content p")[2].text and soup.select("div.article_body_content p")[0].text !="":
                        body = soup.select("div.article_body_content p")[2:] 
                    elif "Release" not in soup.select("div.article_body_content p")[3].text and soup.select("div.article_body_content p")[0].text !="":
                        body = soup.select("div.article_body_content p")[3:] 
                    else:
                        body = soup.select("div.article_body_content p")[4:] 

                    body_text = ""
                    for item in body:
                        body_text += item.text

                else:
                    # regex capture any text before "Developer:" and after "review"
                    pattern = re.compile(r'review(.+?)\nDeveloper:', re.DOTALL)
                    match = re.search(pattern, brief_str)
                    if match:
                        text = match.group(1).strip()
                        # remove everything in <> and <> itself, if any
                        brief_text = re.sub(r'<.*?>', '', text)

                        print(f"index{i} is Type I, format 7 - {element['Title']}: {element['URL']}")

                        # extract review
                        body = soup.select("div.article_body_content p")[2:]
                        body_text = ""
                        for item in body:
                            body_text += item.text

                    else:
                        if "Developer" in brief_str: # the text starts with developer info, no brief can be extracted
                            try:
                                brief = soup.select("em")[0].text
                                brief_text = brief

                                print(f"index{i} is Type I, format 8 - {element['Title']}: {element['URL']}")

                            except IndexError:
                                brief_text = "n/a"

                                print(f"index{i} is Type II, format 1 - {element['Title']}: {element['URL']}")
            
                            # extract review
                            if "Release" not in soup.select("div.article_body_content p")[0].text and soup.select("div.article_body_content p")[0].text !="":
                                body = soup.select("div.article_body_content p")[0:]
                            elif "Release" not in soup.select("div.article_body_content p")[1].text and soup.select("div.article_body_content p")[0].text !="":
                                body = soup.select("div.article_body_content p")[1:] 
                            elif "Release" not in soup.select("div.article_body_content p")[2].text and soup.select("div.article_body_content p")[0].text !="":
                                body = soup.select("div.article_body_content p")[2:] 
                            elif "Release" not in soup.select("div.article_body_content p")[3].text and soup.select("div.article_body_content p")[0].text !="":
                                body = soup.select("div.article_body_content p")[3:] 
                            else:
                                body = soup.select("div.article_body_content p")[4:] 

                            body_text = ""
                            for item in body:
                                body_text += item.text
        
                        else:
                            brief_text = brief_str

                            print(f"index{i} is Type I, format 7 - {element['Title']}: {element['URL']}")

                            # extract review
                            body = soup.select("div.article_body_content p")[2:]
                            body_text = ""
                            for item in body:
                                body_text += item.text

            try:
                developer_info = developer_tag.next_sibling.strip()
                developers.append(developer_info)
            except TypeError:
                developer_info = developer_tag.next_sibling.next_sibling.strip()
                developers.append(developer_info)
                        
        else:  # no info can be scrapped at all, only the body text
            print(f"index{i} is Type II, format 3 - {element['Title']}: {element['URL']}")
            developers.append("n/a")

            # but Premature Evaluation is different, its first paragraph of body text can be the brief
            # extract review
            body = (soup.select("div.article_body_content p"))
            body_text = ""
            if "Premature Evaluation" in str(body):
                brief_text = body[0].text.replace("\n","")
                for item in body[1:]:
                    body_text += item.text
            else:
                brief_text = "n/a"
                for item in body:
                    body_text += item.text
   
    briefs.append(brief_text)
    updated_body_text = body_text.replace(
        "\nThis review is based on a copy of the game provided by the publisher.",""
        ).replace(
            "Manage cookie settings", ""
            ).replace(
                "To see this content please enable targeting cookies.", "")
    review = {}
    review['review'] = updated_body_text
    reviews.append(review)
# Out:
# index0 is Type I, format 1 - Last Train Home review: freezing to death in the Russian Civil War shouldn't be this entertaining: https://www.rockpapershotgun.com/last-train-home-review
# index1 is Type I, format 1 - SteamWorld Build review: joyful citybuilding and delightful dungeon digging: https://www.rockpapershotgun.com/steamworld-build-review
# index2 is Type I, format 1 - Knuckle Sandwich review: a turn-based RPG that's a little too random: https://www.rockpapershotgun.com/knuckle-sandwich-review
# index3 is Type I, format 1 - Flashback 2 review: a broken travesty of a retro revival: https://www.rockpapershotgun.com/flashback-2-review
# index4 is Type I, format 1 - Small Saga review: a short, story-heavy RPG that's light on challenge: https://www.rockpapershotgun.com/small-saga-review
# index5 is Type I, format 1 - Call Of Duty: Modern Warfare 3 multiplayer review: a tiring nostalgia trip: https://www.rockpapershotgun.com/call-of-duty-modern-warfare-3-multiplayer-review
# index6 is Type I, format 1 - Loddlenaut review: a cute, but simple ocean clean-up adventure: https://www.rockpapershotgun.com/loddlenaut-review
# index7 is Type I, format 1 - Naheulbeuk’s Dungeon Master review: a valiant parody of a satire-proof genre: https://www.rockpapershotgun.com/naheulbeuks-dungeon-master-review
# index8 is Type I, format 1 - American Arcadia review: a stylish, cinematic neo-Truman Show platformer: https://www.rockpapershotgun.com/american-arcadia-review
# index9 is Type I, format 1 - Persona 5 Tactica review: middling turn-based strategy built for Persona-likers: https://www.rockpapershotgun.com/persona-5-tactica-review
# index10 is Type I, format 1 - Warhammer Age Of Sigmar: Realms Of Ruin review: a decent RTS heavy on micromanagement: https://www.rockpapershotgun.com/warhammer-age-of-sigmar-realms-of-ruin-review
# index11 is Type I, format 1 - Call Of Duty: Modern Warfare 3 campaign review: the Price is wrong: https://www.rockpapershotgun.com/call-of-duty-modern-warfare-3-campaign-review
# index12 is Type I, format 1 - Like A Dragon Gaiden: The Man Who Erased His Name review: a rebirth marred by repetition: https://www.rockpapershotgun.com/like-a-dragon-gaiden-the-man-who-erased-his-name-review
# index13 is Type I, format 1 - Cobalt Core review: rootin' tootin' timeloop space shootin': https://www.rockpapershotgun.com/cobalt-core-review
# index14 is Type I, format 1 - The Talos Principle 2 review: masterful puzzles that will make your head spin with dizzying delight: https://www.rockpapershotgun.com/the-talos-principle-2-review
# index15 is Type I, format 1 - Football Manager 2024 review: One last iteration of the most comprehensive management sim going: https://www.rockpapershotgun.com/football-manager-2024-review
# index16 is Type I, format 1 - The Invincible review: missteps hold back this (space)walking sim: https://www.rockpapershotgun.com/the-invincible-review
# index17 is Type I, format 1 - RoboCop: Rogue City review: a good RoboCop game, but a middling FPS: https://www.rockpapershotgun.com/robocop-rogue-city-review
# index18 is Type I, format 1 - Alan Wake 2 review: singular, hyperbolic horror: https://www.rockpapershotgun.com/alan-wake-2-review
# index19 is Type I, format 1 - Thirsty Suitors review: a breezy, janky RPG with emotional maturity: https://www.rockpapershotgun.com/thirsty-suitors-review
# index20 is Type I, format 1 - Jusant review: a show don't tell masterpiece: https://www.rockpapershotgun.com/jusant-review
# index21 is Type I, format 1 - The Lord Of The Rings: Return To Moria review: solid cozy survival fun for a group of pals: https://www.rockpapershotgun.com/the-lord-of-the-rings-return-to-moria-review
# index22 is Type I, format 1 - Song Of Nunu: A League Of Legends Story review: simple 3D platforming with lots of heart: https://www.rockpapershotgun.com/song-of-nunu-a-league-of-legends-story-review-simple-3d-platforming-with-lots-of-heart
# index23 is Type I, format 1 - Subpar Pool review: the most charming pool-golf you'll ever play, but not quite a hole(down) in one: https://www.rockpapershotgun.com/subpar-pool-review
# index24 is Type I, format 1 - Ghostrunner 2 review: an unforgiving cyberpunk slasher you'll either love or despise: https://www.rockpapershotgun.com/ghostrunner-2-review
# index25 is Type I, format 1 - Cities: Skylines 2 review: A standard-bearer that ought to have higher standards: https://www.rockpapershotgun.com/cities-skylines-2-review
# index26 is Type I, format 1 - Urbo review: Threes meets Dorfromantik in this chill puzzler: https://www.rockpapershotgun.com/urbo-review
# index27 is Type I, format 1 - World Of Horror review: a weird and wonderful horror adventure in time for Halloween: https://www.rockpapershotgun.com/world-of-horror-review
# index28 is Type I, format 1 - Endless Dungeon review: an excellently moreish roguelike about opening doors: https://www.rockpapershotgun.com/endless-dungeon-review
# index29 is Type I, format 1 - Star Trek: Infinite review: Not exactly a strategy pioneer, but still an enjoyable journey: https://www.rockpapershotgun.com/star-trek-infinite-review
# index30 is Type I, format 1 - Lords Of The Fallen review: realm-hopping magic can't keep this Soulslike from getting on your nerves: https://www.rockpapershotgun.com/lords-of-the-fallen-review
# index31 is Type I, format 1 - Saltsea Chronicles review: an enthralling high seas mystery adventure: https://www.rockpapershotgun.com/saltsea-chronicles-review
# index32 is Type I, format 1 - Total War: Pharaoh review: a towering monument to a broken release schedule: https://www.rockpapershotgun.com/total-war-pharaoh-review
# index33 is Type I, format 1 - The Lamplighters League review: I like you, but after a while you do my head in: https://www.rockpapershotgun.com/the-lamplighters-league-review
# index34 is Type I, format 1 - Counter-Strike 2 review: a big change to an unparalleled FPS, but it could be something special: https://www.rockpapershotgun.com/counter-strike-2-review
# index35 is Type I, format 1 - Assassin's Creed Mirage review: the most enjoyable Assassin's Creed game for years: https://www.rockpapershotgun.com/assassins-creed-mirage-review
# index36 is Type I, format 1 - Station To Station review: all aboard the prettiest puzzle express, calling at fun junction: https://www.rockpapershotgun.com/station-to-station-review
# index37 is Type I, format 1 - Cocoon review: this puzzler is a world-hopping delight: https://www.rockpapershotgun.com/cocoon-review
# index38 is Type I, format 1 - El Paso, Elsewhere review: a cosmic third-person shooter from a forgotten age: https://www.rockpapershotgun.com/el-paso-elsewhere-review
# index39 is Type I, format 1 - Mineko's Night Market review: a catatonic craft 'em up: https://www.rockpapershotgun.com/minekos-night-market-review
# index40 is Type I, format 1 - Payday 3 review: this co-op crime 'em up has lovely levels, but it won't steal your heart: https://www.rockpapershotgun.com/payday-3-review
# index41 is Type I, format 1 - Cyberpunk 2077: Phantom Liberty review: perhaps the best expansion pack ever made: https://www.rockpapershotgun.com/cyberpunk-2077-phantom-liberty-review
# index42 is Type I, format 1 - Lies Of P review: the closest we'll get to Bloodborne on PC, probably: https://www.rockpapershotgun.com/lies-of-p-review
# index43 is Type I, format 1 - Mortal Kombat 1 review: klassic killing meets kampaign kliché: https://www.rockpapershotgun.com/mortal-kombat-1-review
# index44 is Type I, format 1 - Bomb Rush Cyberfunk review: stylish, funky and flawed: https://www.rockpapershotgun.com/bomb-rush-cyberfunk-review
# index45 is Type I, format 1 - Dune: Spice Wars review: a compulsive 4X that both nails and wastes its source material: https://www.rockpapershotgun.com/dune-spice-wars-review
# index46 is Type I, format 1 - Gunbrella review: a stylish 2D platformer with bullets in its brolly: https://www.rockpapershotgun.com/gunbrella-review
# index47 is Type I, format 1 - Hauma - A Detective Noir Story review: Indiana Jones meets visual novel meets ridiculous cop show: https://www.rockpapershotgun.com/hauma-a-detective-noir-story-review
# index48 is Type I, format 1 - Mythforce review: Saturday morning skeletons and familiar roguelike comforts: https://www.rockpapershotgun.com/mythforce-review
# index49 is Type I, format 1 - Affogato review: Persona goes on a coffee date with tower assault dungeon crawling: https://www.rockpapershotgun.com/affogato-review
# index50 is Type I, format 1 - Starfield review: an impressive RPG that's so big it feels small: https://www.rockpapershotgun.com/starfield-review
# index51 is Type I, format 1 - Starfield review: surely, the best Starfield game you'll ever play: https://www.rockpapershotgun.com/starfield-itch-review
# index52 is Type I, format 1 - Sea Of Stars review: a slick RPG that harks back to the Chrono Trigger classics: https://www.rockpapershotgun.com/sea-of-stars-review
# index53 is Type I, format 1 - Armored Core 6: Fires Of Rubicon review: FromSoftware's full spectrum mech experience mostly delivers: https://www.rockpapershotgun.com/armored-core-6-fires-of-rubicon-review
# index54 is Type I, format 1 - Fort Solis review: a handsome haunted spacehouse with a deflating shortage of spectres: https://www.rockpapershotgun.com/fort-solis-review
# index55 is Type I, format 1 - Immortals Of Aveum review: a sometimes fun magical romp that lacks spark: https://www.rockpapershotgun.com/immortals-of-aveum-review
# index56 is Type I, format 1 - Six Ages 2: Lights Going Out review: a fascinating story-generator with a wealth of possibilities: https://www.rockpapershotgun.com/six-ages-2-lights-going-out-review
# index57 is Type I, format 1 - Blasphemous 2 review: a worthy 2D Dark Souls tribute drenched in literal Catholicism: https://www.rockpapershotgun.com/blasphemous-2-review
# index58 is Type I, format 1 - The Cosmic Wheel Sisterhood review: a wonderfully witchy fable told through player-created Tarot: https://www.rockpapershotgun.com/cosmic-wheel-sisterhood-review
# index59 is Type I, format 1 - Shadow Gambit: The Cursed Crew review: an all-time treasure: https://www.rockpapershotgun.com/shadow-gambit-the-cursed-crew-review
# index60 is Type I, format 1 - Gord review: fertile ground covered in stagnant water, also swamps: https://www.rockpapershotgun.com/gord-review
# index61 is Type I, format 1 - Baldur's Gate 3 review: the rumours are true, this is a really good RPG: https://www.rockpapershotgun.com/baldurs-gate-3-review
# index62 is Type I, format 1 - Turbo Overkill review: a relentless retro FPS, best enjoyed in bursts: https://www.rockpapershotgun.com/turbo-overkill-review
# index63 is Type I, format 1 - Atlas Fallen review: middling action adventuring upheld by (mostly) stellar combat: https://www.rockpapershotgun.com/atlas-fallen-review
# index64 is Type I, format 1 - Stray Gods: The Roleplaying Musical review: a melodic adventure with something to sing about: https://www.rockpapershotgun.com/stray-gods-the-roleplaying-musical-review
# index65 is Type I, format 1 - Videoverse review: hold onto your heartstrings: https://www.rockpapershotgun.com/videoverse-review
# index66 is Type I, format 1 - Venba review: a brief, but touching cooking puzzler with a heap of heart: https://www.rockpapershotgun.com/venba-review
# index67 is Type I, format 1 - F1 Manager 2023 review: accurate to a fault: https://www.rockpapershotgun.com/f1-manager-2023-review
# index68 is Type I, format 1 - Lakeburg Legacies review: what's love got to do with town management?: https://www.rockpapershotgun.com/lakeburg-legacies-review
# index69 is Type I, format 1 - ΔV: Rings Of Saturn review: turns asteroid mining lead into space game gold: https://www.rockpapershotgun.com/v-rings-of-saturn-review
# index70 is Type I, format 1 - Exoprimal review: fun dino-slaying for some, dull repetition for most: https://www.rockpapershotgun.com/exoprimal-review
# index71 is Type I, format 1 - Remnant II review: fast, brutal combat meets procedural dimension-hopping in this ambitious sequel: https://www.rockpapershotgun.com/remnant-ii-review
# index72 is Type I, format 1 - Might & Magic: Clash Of Heroes - Definitive Edition review: return of the match-3 king?: https://www.rockpapershotgun.com/might-magic-clash-of-heroes-definitive-edition-review
# index73 is Type I, format 1 - Let's! Revolution! review: the fantasy Minesweeper roguelite you never knew you needed: https://www.rockpapershotgun.com/lets-revolution-review
# index74 is Type I, format 1 - Full Void review: a cinematic platformer that channels the spirit of Another World: https://www.rockpapershotgun.com/full-void-review
# index75 is Type I, format 1 - Exoprimal review-in-progress: somehow makes team dino-slaying a snoozefest: https://www.rockpapershotgun.com/exoprimal-review-in-progress
# index76 is Type I, format 1 - Viewfinder review: a mind-bending puzzler where perspective is everything: https://www.rockpapershotgun.com/viewfinder-review
# index77 is Type I, format 1 - Jagged Alliance 3 review: a strong sequel that aims to refresh, not merely repeat: https://www.rockpapershotgun.com/jagged-alliance-3-review
# index78 is Type I, format 1 - Oxenfree II: Lost Signals review: a spooky, supernatural adventure that needs fine-tuning: https://www.rockpapershotgun.com/oxenfree-2-lost-signals-review
# index79 is Type I, format 3 - Trepang2 review: It's an indie F.E.A.R.: https://www.rockpapershotgun.com/trepang2-review-its-an-indie-fear
# index80 is Type I, format 1 - Ghost Trick: Phantom Detective review: a glorious remaster that's still to die for: https://www.rockpapershotgun.com/ghost-trick-phantom-detective-remastered-review
# index81 is Type I, format 1 - Aliens: Dark Descent review: decent, if desperate to sit with the cool console kids: https://www.rockpapershotgun.com/aliens-dark-descent-review
# index82 is Type I, format 1 - Dordogne review: don't brush off this sweet summer adventure: https://www.rockpapershotgun.com/dordogne-review
# index83 is Type I, format 1 - Park Beyond review: more style than substance, but sometimes that's the point: https://www.rockpapershotgun.com/park-beyond-review
# index84 is Type I, format 1 - Mask Of The Rose review: a lavish gothic dating sim that's a little light on romance: https://www.rockpapershotgun.com/mask-of-the-rose-review
# index85 is Type I, format 1 - Amnesia: The Bunker review: a grim yet refreshing horror bottle episode: https://www.rockpapershotgun.com/amnesia-the-bunker-review
# index86 is Type I, format 1 - Slayers X: Terminal Aftermath: Vengance of the Slayer review: a boisterous Hypnospace spin-off that's an obnoxious gem: https://www.rockpapershotgun.com/slayers-x-terminal-aftermath-vengance-of-the-slayer-review-a-boisterous-hypnospace-spin-off-thats-an-obnoxious-gem
# index87 is Type I, format 1 - The Tartarus Key review: an absolutely nails thriller-puzzler that's worth the effort: https://www.rockpapershotgun.com/the-tartarus-key-review
# index88 is Type I, format 1 - Diablo IV review: 2023's prettiest RSI machine: https://www.rockpapershotgun.com/diablo-iv-review
# index89 is Type I, format 1 - Street Fighter 6 review: the former champ is finally back on top: https://www.rockpapershotgun.com/street-fighter-6-review
# index90 is Type I, format 1 - System Shock remake review: Nightdive rebuilds the immersive sim mothership just as it was: https://www.rockpapershotgun.com/system-shock-review
# index91 is Type I, format 1 - The Lord Of The Rings: Gollum review: I hates it: https://www.rockpapershotgun.com/the-lord-of-the-rings-gollum-review
# index92 is Type I, format 1 - Miasma Chronicles review: this tactically sound turn-based post-apocalypse is short on fresh ideas: https://www.rockpapershotgun.com/miasma-chronicles-review
# index93 is Type I, format 1 - Warhammer 40,000: Boltgun review: gloriously maximalist shooting and sawing in the 41st millennium: https://www.rockpapershotgun.com/warhammer-40000-boltgun-review
# index94 is Type I, format 1 - Humanity review: perfect puzzles pumped with existential hot air: https://www.rockpapershotgun.com/humanity-review
# index95 is Type I, format 1 - Planet Of Lana review: a gorgeous sci-fi tale that shoots for the stars: https://www.rockpapershotgun.com/planet-of-lana-review
# index96 is Type I, format 1 - HROT review: serviceable Soviet shooter saved by scintillating level design: https://www.rockpapershotgun.com/hrot-review
# index97 is Type I, format 1 - Lego 2K Drive review: a charming open world kart racer slowed by live service roadblocks: https://www.rockpapershotgun.com/lego-2k-drive-review-a-charming-open-world-kart-racer-slowed-by-live-service-roadblocks
# index98 is Type I, format 1 - Darkest Dungeon 2 review: a fast-paced roguelite down gloomy roads: https://www.rockpapershotgun.com/darkest-dungeon-2-review
# index99 is Type I, format 1 - Redfall review: an open world FPS drained of Arkane's magic: https://www.rockpapershotgun.com/redfall-review
# index100 is Type I, format 1 - Age Of Wonders 4 review: a plain good magical strategy that hasn't really turned me either way: https://www.rockpapershotgun.com/age-of-wonders-4-review
# index101 is Type I, format 1 - Cassette Beasts review: dropping the mic on the Pokémon-like: https://www.rockpapershotgun.com/cassette-beasts-review
# index102 is Type I, format 1 - Star Wars Jedi: Survivor review: a good Star Wars epic with a lot of collectibles: https://www.rockpapershotgun.com/star-wars-jedi-survivor-review
# index103 is Type I, format 1 - Honkai: Star Rail review: a slick, anime-infused RPG bursting with potential: https://www.rockpapershotgun.com/honkai-star-rail-review
# index104 is Type I, format 1 - Stranded: Alien Dawn review: a survival sim that nails the crashlanding: https://www.rockpapershotgun.com/stranded-alien-dawn-review
# index105 is Type I, format 1 - Oxygen review: a windy post-apocalyptic city builder that won't exceed expectations: https://www.rockpapershotgun.com/oxygen-review
# index106 is Type I, format 1 - Coffee Talk Episode 2: Hibiscus & Butterfly review: more sweet tales from the fantasy café: https://www.rockpapershotgun.com/coffee-talk-episode-2-hibiscus-and-butterfly-review
# index107 is Type I, format 1 - Dead Island 2 review: as disposably entertaining as an electrified pipe-wrench: https://www.rockpapershotgun.com/dead-island-2-review
# index108 is Type I, format 1 - Minecraft Legends review: a colourful RTS limited by its own small ambitions: https://www.rockpapershotgun.com/minecraft-legends-review
# index109 is Type I, format 1 - Sherlock Holmes The Awakened review: a creepy Lovecraftian jaunt for Frogwares fans: https://www.rockpapershotgun.com/sherlock-holmes-the-awakened-review
# index110 is Type I, format 1 - Wartales review: a grimy medieval fantasy RPG rife with emergent stories: https://www.rockpapershotgun.com/wartales-review
# index111 is Type I, format 1 - Road 96: Mile 0 review: an unexpected but enjoyable mashup prequel: https://www.rockpapershotgun.com/road-96-mile-0-review-an-unexpected-but-enjoyable-mashup-prequel
# index112 is Type I, format 1 - Everspace 2 review: noughties but nice: https://www.rockpapershotgun.com/everspace-2-review
# index113 is Type I, format 1 - Wildfrost review: cute, compelling, and chaotic card battling: https://www.rockpapershotgun.com/wildfrost-review
# index114 is Type I, format 1 - The Last Worker review: this dystopian satire on automated jobs rather labours its point: https://www.rockpapershotgun.com/the-last-worker-review
# index115 is Type I, format 1 - Crime Boss: Rockay City review: a baffling and incoherent Paydaylike: https://www.rockpapershotgun.com/crime-boss-rockay-city-review
# index116 is Type I, format 1 - Terra Nil review: a pretty reverse citybuilder that struggles to find its identity: https://www.rockpapershotgun.com/terra-nil-review
# index117 is Type I, format 1 - The Great War: Western Front review: alternately compelling and exhausting, which is probably deliberate: https://www.rockpapershotgun.com/the-great-war-western-front-review
# index118 is Type I, format 1 - Dredge review: spooky ocean thrills that reel you in for more: https://www.rockpapershotgun.com/dredge-review
# index119 is Type I, format 1 - Storyteller review: a delightful bookish puzzler that ends before you're ready: https://www.rockpapershotgun.com/storyteller-review
# index120 is Type I, format 1 - Tchia review: a gorgeous open-world adventure bursting with heart: https://www.rockpapershotgun.com/tchia-review
# index121 is Type I, format 1 - Resident Evil 4 remake review: an exceptional return to one of the greatest action games of all time: https://www.rockpapershotgun.com/resident-evil-4-remake-review
# index122 is Type I, format 1 - Paranormasight: The Seven Mysteries Of Honjo review: a hair-raising and subversive horror visual novel: https://www.rockpapershotgun.com/paranormasight-the-seven-mysteries-of-honjo-review
# index123 is Type I, format 1 - The Wreck review: a raw road trip down memory lane: https://www.rockpapershotgun.com/the-wreck-review
# index124 is Type I, format 1 - Fatal Frame: Mask of the Lunar Eclipse review: a frightfully frustrating flashback: https://www.rockpapershotgun.com/fatal-frame-project-zero-mask-of-the-lunar-eclipse-review
# index125 is Type I, format 1 - Figment 2: Creed Valley review: a fun musical adventure a beat behind its predecessor: https://www.rockpapershotgun.com/figment-2-creed-valley-review
# index126 is Type I, format 1 - Outlanders review: a charming town builder with a hidden sense of humour: https://www.rockpapershotgun.com/outlanders-review
# index127 is Type I, format 2 - Wo Long: Fallen Dynasty review: a streamlined Nioh with an encouraging spirit: https://www.rockpapershotgun.com/wo-long-fallen-dynasty-review
# index128 is Type I, format 1 - Sons Of The Forest early access review: a gorgeous island filled with cannibals and little else so far: https://www.rockpapershotgun.com/sons-of-the-forest-early-access-review
# index129 is Type I, format 1 - Phantom Brigade review: entertaining mech battles carry a toothless campaign: https://www.rockpapershotgun.com/phantom-brigade-review
# index130 is Type I, format 1 - Kerbal Space Program 2 early access review: a catastrophic re-entry: https://www.rockpapershotgun.com/kerbal-space-program-2-early-access-review
# index131 is Type I, format 1 - The Settlers: New Allies review: a tedious blend of management sim and RTS that simply doesn't work: https://www.rockpapershotgun.com/the-settlers-new-allies-review
# index132 is Type I, format 1 - Wild Hearts review: an impressive monster battler that's perfect for beast-brawling newcomers: https://www.rockpapershotgun.com/wild-hearts-review
# index133 is Type I, format 1 - The Pale Beyond review: a captivating survival game full of drama and despair: https://www.rockpapershotgun.com/the-pale-beyond-review
# index134 is Type I, format 1 - Company Of Heroes 3 review: a glorious comeback for this WW2 RTS: https://www.rockpapershotgun.com/company-of-heroes-3-review
# index135 is Type I, format 1 - Birth review: a comforting puzzle game about death and decay: https://www.rockpapershotgun.com/birth-review
# index136 is Type I, format 2 - Atomic Heart review: a mad science experiment that yields mixed results: https://www.rockpapershotgun.com/atomic-heart-review
# index137 is Type I, format 2 - Like A Dragon Ishin review: a step backwards in the best way: https://www.rockpapershotgun.com/like-a-dragon-ishin-review
# index138 is Type I, format 1 - Octopath Traveler 2 review: the flawed JRPG returns for more of the same: https://www.rockpapershotgun.com/octopath-traveler-2-review
# index139 is Type I, format 1 - Returnal review: an immaculate third-person shooter that may keep you in its loop forever: https://www.rockpapershotgun.com/returnal-review
# index140 is Type I, format 1 - Pharaoh A New Era review: the venerable city builder king has never looked better: https://www.rockpapershotgun.com/pharaoh-a-new-era-review
# index141 is Type I, format 1 - Blanc review: heartwarming co-op, but its weak second half leaves you out in the cold: https://www.rockpapershotgun.com/blanc-review
# index142 is Type I, format 2 - Wanted: Dead review: third-person action that's more dead than alive: https://www.rockpapershotgun.com/wanted-dead-review-third-person-action-thats-more-dead-than-alive
# index143 is Type I, format 1 - Industries of Titan review: a curious hybrid builder that's less than the sum of its parts: https://www.rockpapershotgun.com/industries-of-titan-review-a-curious-hybrid-builder-thats-less-than-the-sum-of-its-parts
# index144 is Type I, format 1 - Deliver Us Mars review: a family and a planet in crisis: https://www.rockpapershotgun.com/deliver-us-mars-review
# index145 is Type I, format 1 - Hi-Fi Rush review: it’s a bangers bonanza in this electrifying rhythm-action game: https://www.rockpapershotgun.com/hi-fi-rush-review
# index146 is Type I, format 1 - Forspoken review: sometimes fun, often annoying, always empty: https://www.rockpapershotgun.com/forspoken-review
# index147 is Type I, format 1 - Dead Space review: an excellent remake of a horror classic: https://www.rockpapershotgun.com/dead-space-review
# index148 is Type I, format 1 - Season: A Letter To The Future review: a melancholy travelogue of a gorgeous post-war world: https://www.rockpapershotgun.com/season-a-letter-to-the-future-review
# index149 is Type I, format 1 - Mahokenshi review: a deckbuilder that sticks you with the pointy end: https://www.rockpapershotgun.com/mahokenshi-review
# index150 is Type I, format 1 - A Space For The Unbound review: a supernatural teen romance with a wonderful sense of time and place: https://www.rockpapershotgun.com/a-space-for-the-unbound-review
# index151 is Type I, format 1 - Farlanders review: a Martian city builder that’s rather rocky: https://www.rockpapershotgun.com/farlanders-review
# index152 is Type I, format 1 - Aquatico review: a soothing underwater city builder that neglects the dangers of the deep: https://www.rockpapershotgun.com/aquatico-review
# index153 is Type I, format 1 - Lil Gator Game review: a heartfelt adventure about childhood antics: https://www.rockpapershotgun.com/lil-gator-game-review
# index154 is Type I, format 1 - Warhammer 40K: Darktide review: brilliantly grisly co-op: https://www.rockpapershotgun.com/warhammer-40000-darktide-review
# index155 is Type I, format 1 - Crisis Core - Final Fantasy VII - Reunion review: polished story filler that's a missed opportunity after FF7 Remake: https://www.rockpapershotgun.com/crisis-core-final-fantasy-vii-reunion-review
# index156 is Type I, format 1 - Choo-Choo Charles review: off the rails survival horror: https://www.rockpapershotgun.com/choo-choo-charles-review
# index157 is Type I, format 1 - Dwarf Fortress review: the legendary colony sim gets a welcome facelift for Steam: https://www.rockpapershotgun.com/dwarf-fortress-steam-review
# index158 is Type I, format 1 - Ixion review: an intricate management sim wrapped in a stirring space opera: https://www.rockpapershotgun.com/ixion-review
# index159 is Type I, format 1 - Kynseed review: a promising RPG, but not all its promises are fulfilled: https://www.rockpapershotgun.com/kynseed-review
# index160 is Type I, format 1 - The Callisto Protocol review: could be silly, bloody space fun if it ran on PC: https://www.rockpapershotgun.com/the-callisto-protocol-review
# index161 is Type I, format 1 - Marvel's Midnight Suns review: the best Marvel game yet: https://www.rockpapershotgun.com/marvels-midnight-suns-review
# index162 is Type I, format 2 - Call Of Duty Warzone 2 review: a worthy successor: https://www.rockpapershotgun.com/call-of-duty-warzone-2-review
# index163 is Type I, format 1 - The Dark Pictures Anthology: The Devil In Me review: fourth time’s charming but still not a charm: https://www.rockpapershotgun.com/the-dark-pictures-anthology-the-devil-in-me-review
# index164 is Type I, format 1 - Goat Simulator 3 review: more than the sum of its fart noises: https://www.rockpapershotgun.com/goat-simulator-3-review
# index165 is Type I, format 1 - Pentiment review: a captivating murder mystery spanning 25 years of rich medieval history: https://www.rockpapershotgun.com/pentiment-review
# index166 is Type I, format 1 - Somerville review: an intimate look at the apocalypse: https://www.rockpapershotgun.com/somerville-review
# index167 is Type I, format 1 - Sonic Frontiers review: a patchwork playground that veers between fun and frustration: https://www.rockpapershotgun.com/sonic-frontiers-review
# index168 is Type I, format 1 - Flat Eye review: a petrol station management sim powered by the same dark fuel as Black Mirror: https://www.rockpapershotgun.com/flat-eye-review
# index169 is Type I, format 1 - Floodland review: city-building with a focus on community: https://www.rockpapershotgun.com/floodland-review
# index170 is Type I, format 1 - Harvestella review: a traditional JRPG with a farming twist: https://www.rockpapershotgun.com/harvestella-review
# index171 is Type I, format 1 - Tactics Ogre: Reborn review: a 90s strategy classic that still holds up today: https://www.rockpapershotgun.com/tactics-ogre-reborn-review
# index172 is Type I, format 1 - A Little To The Left review: everything in its right place: https://www.rockpapershotgun.com/a-little-to-the-left-review
# index173 is Type I, format 1 - How To Say Goodbye review: a cozy, compassionate puzzle game about death: https://www.rockpapershotgun.com/how-to-say-goodbye-review
# index174 is Type I, format 1 - Call Of Duty: Modern Warfare 2 (multiplayer) review: slick shooting that rarely misfires: https://www.rockpapershotgun.com/call-of-duty-modern-warfare-2-multiplayer-review
# index175 is Type I, format 1 - Vampire Survivors review: an unquestionably compulsive treat until you reach the endgame: https://www.rockpapershotgun.com/vampire-survivors-review
# index176 is Type I, format 1 - The Chant review: needs more weird: https://www.rockpapershotgun.com/the-chant-review
# index177 is Type I, format 1 - Ghost Song review: a melancholy Metroidvania with a hint of Hollow Knight: https://www.rockpapershotgun.com/ghost-song-review
# index178 is Type I, format 1 - Signalis review: PS1 survival horror fans, rejoice: https://www.rockpapershotgun.com/signalis-review
# index179 is Type I, format 1 - Mount & Blade 2: Bannerlord review: far more cows, but very little fresh butter: https://www.rockpapershotgun.com/mount-blade-2-bannerlord-review
# index180 is Type I, format 1 - Butterfly Soup 2 review: a heartfelt return of the gay baseball teens: https://www.rockpapershotgun.com/butterfly-soup-2-review
# index181 is Type I, format 1 - Saturnalia review: a truly unique, beautiful, and exquisite horror game: https://www.rockpapershotgun.com/saturnalia-review
# index182 is Type I, format 1 - Frog Detective 3: Corruption At Cowboy County review: a final farewell to a loveable series: https://www.rockpapershotgun.com/frog-detective-3-corruption-at-cowboy-county-review
# index183 is Type I, format 1 - Call Of Duty: Modern Warfare 2 (campaign) review: a mix of the spectacular and the middling: https://www.rockpapershotgun.com/call-of-duty-modern-warfare-2-campaign-review
# index184 is Type I, format 1 - Victoria 3 review: chaotic grand strategy in the age of steam: https://www.rockpapershotgun.com/victoria-3-review
# index185 is Type I, format 2 - Gotham Knights review: an action-RPG dictated by dull numbers and tired combat: https://www.rockpapershotgun.com/gotham-knights-review
# index186 is Type I, format 1 - New Tales From The Borderlands review: thanks, I hate it: https://www.rockpapershotgun.com/new-tales-from-the-borderlands-review
# index187 is Type I, format 2 - A Plague Tale: Requiem review: a feast for the eyes, but its storytelling lacks bite: https://www.rockpapershotgun.com/a-plague-tale-requiem-review
# index188 is Type I, format 1 - Scorn review: a staggeringly impressive horror world with messy combat: https://www.rockpapershotgun.com/scorn-review
# index189 is Type I, format 1 - The Case Of The Golden Idol review: a gripping detective game with echoes of Obra Dinn: https://www.rockpapershotgun.com/the-case-of-the-golden-idol-review
# index190 is Type I, format 1 - Cultic review: crunchy retro-inspired FPS is a vicious, violent delight: https://www.rockpapershotgun.com/cultic-review
# index191 is Type I, format 1 - Coral Island early access review: a pretty Stardew-like that makes farming a little easier: https://www.rockpapershotgun.com/coral-island-early-access-review
# index192 is Type I, format 1 - Moonbreaker early access review: fun tabletop battling that's a bit too miniature right now: https://www.rockpapershotgun.com/moonbreaker-early-access-review
# index193 is Type I, format 1 - Overwatch 2 review-in-progress: tonnes of fun marred by context and expectations: https://www.rockpapershotgun.com/overwatch-2-review-in-progress
# index194 is Type I, format 1 - The Excavation Of Hob's Barrow review: an emotive and doomy folk horror adventure: https://www.rockpapershotgun.com/the-excavation-of-hobs-barrow-review
# index195 is Type I, format 1 - Dome Keeper review: a small, but perfectly formed tower defence game that strikes gold: https://www.rockpapershotgun.com/dome-keeper-review
# index196 is Type I, format 1 - Serial Cleaners review: stealth-action body disposal makes for bursts of bloody fun: https://www.rockpapershotgun.com/serial-cleaners-review
# index197 is Type I, format 1 - Grounded review: a survival game with the best baddies around: https://www.rockpapershotgun.com/grounded-review
# index198 is Type I, format 1 - Wayward Strand review: a heartfelt story told through an intricate timepiece: https://www.rockpapershotgun.com/wayward-strand-review
# index199 is Type I, format 1 - The DioField Chronicle review: deep real-time strategy that gets mired in its own plot: https://www.rockpapershotgun.com/the-diofield-chronicle-review
# index200 is Type I, format 1 - Beacon Pines review: a cosy horror adventure game that succeeds on the strength of its characters: https://www.rockpapershotgun.com/beacon-pines-review
# index201 is Type I, format 1 - Hyper Demon review: a deadly, unfriendly, and utterly stunning FPS: https://www.rockpapershotgun.com/hyper-demon-review
# index202 is Type I, format 1 - Return To Monkey Island review: a perfect new entry into a beloved old series: https://www.rockpapershotgun.com/return-to-monkey-island-review
# index203 is Type I, format 1 - The Wandering Village early access review: a gorgeous city-builder with a loveable colossus: https://www.rockpapershotgun.com/the-wandering-village-early-access-review
# index204 is Type I, format 1 - Foretales review: channelling Hand Of Fate's tabletop deckbuilding to great effect: https://www.rockpapershotgun.com/foretales-review
# index205 is Type I, format 1 - Disney Dreamlight Valley early access review: a life-sim for Mickey stans: https://www.rockpapershotgun.com/disney-dreamlight-valley-early-access-review
# index206 is Type I, format 1 - Metal: Hellsinger review - a rhythm shooter that can be anybody's tempo: https://www.rockpapershotgun.com/metal-hellsinger-review
# index207 is Type I, format 1 - Sunday Gold review: tactical point and click puzzling that fails to mesh: https://www.rockpapershotgun.com/sunday-gold-review
# index208 is Type I, format 1 - Betrayal At Club Low review: a delicious snack-sized espionage RPG set in a nightclub: https://www.rockpapershotgun.com/betrayal-at-club-low-review
# index209 is Type I, format 1 - Temtem review: a Pokemon-like that listens to what fans want: https://www.rockpapershotgun.com/temtem-review
# index210 is Type I, format 1 - Jack Move review: a bite-sized JRPG that blends Neuromancer with Final Fantasy VII: https://www.rockpapershotgun.com/jack-move-review
# index211 is Type I, format 1 - Roadwarden review: a beautifully written visit to a mystery-filled peninsula: https://www.rockpapershotgun.com/roadwarden-review
# index212 is Type I, format 1 - Steelrising review: this steampunk Soulslike take on the French Revolution doesn't execute on its cool premise: https://www.rockpapershotgun.com/steelrising-review
# index213 is Type I, format 1 - Railbound review: a charming, first class puzzler: https://www.rockpapershotgun.com/railbound-review
# index214 is Type I, format 1 - ORX review early access: a moreish tower defence roguelike that already has strong foundations: https://www.rockpapershotgun.com/orx-review-early-access
# index215 is Type I, format 1 - Immortality review: a peeling apart of stories, power and film that can't quite balance on a knife edge: https://www.rockpapershotgun.com/immortality-review
# index216 is Type I, format 1 - Rollerdrome review: a difficult but stylish skater-shooter that'll give you a shot of adrenaline: https://www.rockpapershotgun.com/rollerdrome-review
# index217 is Type I, format 1 - Tinykin review: a fun Pikmin-like bursting with humorous surprises: https://www.rockpapershotgun.com/tinykin-review
# index218 is Type I, format 1 - Saints Row (2022) review: a fun but sadly confused reboot: https://www.rockpapershotgun.com/saints-row-2022-review
# index219 is Type I, format 1 - Cursed To Golf review: a charming golf sim that's stuck in roguelike purgatory: https://www.rockpapershotgun.com/cursed-to-golf-review
# index220 is Type I, format 1 - We Are OFK review: an emotional music biopic that’s a bit too Silicon Valley: https://www.rockpapershotgun.com/we-are-ofk-review
# index221 is Type I, format 1 - Marvel's Spider-Man Remastered review: a fun hero epic that takes the wall-crawler to new heights: https://www.rockpapershotgun.com/marvels-spider-man-remastered-review
# index222 is Type I, format 1 - Cult Of The Lamb review: an adorably twisted cult management game: https://www.rockpapershotgun.com/cult-of-the-lamb-review
# index223 is Type I, format 1 - Lost In Play review: a gorgeous point and click puzzler: https://www.rockpapershotgun.com/lost-in-play-review
# index224 is Type I, format 1 - South Of The Circle review: a Cold War story with emotional highs that fumbles the landing: https://www.rockpapershotgun.com/south-of-the-circle-review
# index225 is Type I, format 1 - Turbo Golf Racing early access review: a great new motorsport takes us one step closer to the car olympics: https://www.rockpapershotgun.com/turbo-golf-racing-early-access-review-a-great-new-motorsport-takes-us-one-step-closer-to-the-car-olympics
# index226 is Type I, format 1 - Hard West 2 review: rootin' tootin' tactical shootin': https://www.rockpapershotgun.com/hard-west-2-review-rootin-tootin-tactical-shootin
# index227 is Type I, format 1 - Two Point Campus review: a relaxed management sim bursting with silliness and seminars: https://www.rockpapershotgun.com/two-point-campus-review-a-relaxed-management-sim-bursting-with-silliness-and-seminars
# index228 is Type I, format 1 - Bear And Breakfast review: a cute but stifling management game: https://www.rockpapershotgun.com/bear-and-breakfast-review-a-cute-but-stifling-management-game
# index229 is Type I, format 1 - Lord Winklebottom Investigates review: a dapper murder mystery with not enough detective work: https://www.rockpapershotgun.com/lord-winklebottom-investigates-review
# index230 is Type I, format 1 - Clanfolk early access review: a settlement sim that's a little too familiar: https://www.rockpapershotgun.com/clanfolk-review-a-settlement-sim-thats-a-little-too-familiar
# index231 is Type I, format 1 - Endling - Extinction Is Forever review: another cute animal survival game that’ll make you cry: https://www.rockpapershotgun.com/endling-extinction-is-forever-review
# index232 is Type I, format 1 - Stray review: one small step for cats, one giant leap for action adventure games: https://www.rockpapershotgun.com/stray-review
# index233 is Type I, format 1 - As Dusk Falls review: a gripping adventure that deserves a prime time slot: https://www.rockpapershotgun.com/as-dusk-falls-review-a-gripping-adventure-that-deserves-a-prime-time-slot
# index234 is Type I, format 1 - Gwent: Rogue Mage review: a solid expansion of an already enticing minigame: https://www.rockpapershotgun.com/gwent-rogue-mage-review-a-solid-expansion-of-an-already-enticing-minigame
# index235 is Type I, format 1 - Escape Academy review: a charming escape room sim that's even better with a bud: https://www.rockpapershotgun.com/escape-academy-review-a-charming-escape-room-sim-thats-even-better-with-a-bud
# index236 is Type I, format 1 - Time On Frog Island review: a laid-back adventure with friendly frog folk: https://www.rockpapershotgun.com/time-on-frog-island-review-a-laid-back-adventure-with-friendly-frog-folk
# index237 is Type I, format 1 - PowerWash Simulator review: a first-person soother built to relieve pressure: https://www.rockpapershotgun.com/powerwash-simulator-review-a-first-person-soother-built-to-relieve-pressure
# index238 is Type I, format 1 - Madison review: entertaining horror that's a bit too clever for its own good: https://www.rockpapershotgun.com/madison-review
# index239 is Type I, format 1 - Witch Strandings review: a cursed, but magical Strand-like: https://www.rockpapershotgun.com/witch-strandings-review
# index240 is Type I, format 1 - Occupy White Walls review: create and curate your own personal art gallery: https://www.rockpapershotgun.com/occupy-white-walls-review
# index241 is Type I, format 1 - Monster Hunter Rise: Sunbreak review: A delightfully difficult expansion that doesn't disappoint: https://www.rockpapershotgun.com/monster-hunter-rise-sunbreak-review-a-delightfully-difficult-expansion-that-doesnt-disappoint
# index242 is Type II, format 3 - The Sims 4 Werewolves is the best supernatural add-on pack yet: https://www.rockpapershotgun.com/the-sims-4-werewolves-impressions
# index243 is Type I, format 1 - Neon White review: a slick, stylish speedrunner with parkour demon murder: https://www.rockpapershotgun.com/neon-white-review
# index244 is Type I, format 1 - Starship Trooper: Terran Command review: a slightly chaotic RTS that needs a bit more flavour: https://www.rockpapershotgun.com/starship-trooper-terran-command-review
# index245 is Type I, format 1 - Teenage Mutant Ninja Turtles: Shredder's Revenge review: a simple sidescroller that's best with buddies: https://www.rockpapershotgun.com/teenage-mutant-ninja-turtles-shredders-revenge-review-a-simple-sidescroller-thats-best-with-buddies
# index246 is Type I, format 1 - The Quarry review: thrills, chills, and only a few spills await: https://www.rockpapershotgun.com/the-quarry-review
# index247 is Type I, format 1 - V Rising early access review: streamlined survival for all types of bloodsucker: https://www.rockpapershotgun.com/v-rising-early-access-review
# index248 is Type I, format 1 - Card Shark review: it's hard to deal yourself a good hand: https://www.rockpapershotgun.com/card-shark-pc-review
# index249 is Type I, format 1 - Silt review: there are plenty of fish in the sea but they're all trying to kill you: https://www.rockpapershotgun.com/silt-review
# index250 is Type I, format 1 - Crossfire: Legion early access review: a well-made RTS that's in too much of a rush: https://www.rockpapershotgun.com/crossfire-legion-early-access-review
# index251 is Type I, format 1 - Hardspace: Shipbreaker review: moreish sci-fi work sim sticks the landing: https://www.rockpapershotgun.com/hardspace-shipbreaker-review-moreish-sci-fi-work-sim-sticks-the-landing
# index252 is Type I, format 1 - Unexplored 2: The Wayfarer's Legacy review: a special, chunky roguesomething: https://www.rockpapershotgun.com/unexplored-2-the-wayfarers-legacy-review
# index253 is Type I, format 1 - Sniper Elite 5 review: too much sprinting, not enough sharpshooting: https://www.rockpapershotgun.com/sniper-elite-5-review
# index254 is Type I, format 1 - Floppy Knights review: a joyful card game that offers more the longer you play: https://www.rockpapershotgun.com/floppy-knights-review
# index255 is Type I, format 1 - My Time At Sandrock early access review: a wild west life simulator that does it all: https://www.rockpapershotgun.com/my-time-at-sandrock-early-access-review
# index256 is Type I, format 1 - Eternal Threads review: Eastenders meets time travel meets electrical safety: https://www.rockpapershotgun.com/eternal-threads-review
# index257 is Type I, format 1 - Vampire: The Masquerade - Swansong review: mystery, intrigue, and walking about: https://www.rockpapershotgun.com/vampire-the-masquerade-swansong-review
# index258 is Type I, format 1 - Gibbon: Beyond The Trees review: a short, but heartfelt ecological adventure: https://www.rockpapershotgun.com/gibbon-beyond-the-trees-review
# index259 is Type I, format 1 - Songs Of Conquest early access review: an already-stylish tactical RPG: https://www.rockpapershotgun.com/songs-of-conquest-early-access-review-an-already-stylish-tactical-rpg
# index260 is Type I, format 1 - Source Of Madness review: machine learning makes this a messy roguelite: https://www.rockpapershotgun.com/source-of-madness-review-machine-learning-makes-this-a-messy-roguelite
# index261 is Type I, format 1 - Eiyuden Chronicle: Rising review: a flat prequel to next year's Suikoden successor Hundred Heroes: https://www.rockpapershotgun.com/eiyuden-chronicle-rising-review
# index262 is Type I, format 1 - Nightmare Reaper review: a retro-styled FPS that hits more than it misses: https://www.rockpapershotgun.com/nightmare-reaper-review-a-retro-styled-fps-that-hits-more-than-it-misses
# index263 is Type I, format 1 - Salt And Sacrifice review: a 2D metroidvania with surprising depth: https://www.rockpapershotgun.com/salt-and-sacrifice-review
# index264 is Type I, format 1 - Trek To Yomi review: a trek that's stunning and tiresome in equal measure: https://www.rockpapershotgun.com/trek-to-yomi-review
# index265 is Type I, format 1 - FixFox review: a lovely weird world to live and repair things in: https://www.rockpapershotgun.com/fixfox-review
# index266 is Type I, format 1 - Warhammer 40K: Chaos Gate - Daemonhunters review: the best kind of tactical mayhem: https://www.rockpapershotgun.com/warhammer-40k-chaos-gate-daemonhunters-review
# index267 is Type I, format 1 - Citizen Sleeper review: a stylish machine with a gooey human heart: https://www.rockpapershotgun.com/citizen-sleeper-review
# index268 is Type I, format 1 - Rogue Legacy 2 review: a dense roguelike you'll want to invest in: https://www.rockpapershotgun.com/rogue-legacy-2-review-a-dense-roguelike-youll-want-to-invest-in
# index269 is Type I, format 1 - Dorfromantik review: the best strategy puzzler two years in a row: https://www.rockpapershotgun.com/dorfromantik-review-pc
# index270 is Type I, format 1 - The Iron Oath early access review: a tactical RPG on a mission to stand out: https://www.rockpapershotgun.com/the-iron-oath-early-access-review
# index271 is Type I, format 1 - Dune: Spice Wars early access review: a compact 4X that falters in the middle: https://www.rockpapershotgun.com/dune-spice-wars-early-access-review
# index272 is Type I, format 1 - Glitchhikers: The Spaces Between review: a good walk ruined: https://www.rockpapershotgun.com/glitchhikers-the-spaces-between-review
# index273 is Type I, format 1 - Turbo Overkill early access review: a retro-inspired FPS that never lets up: https://www.rockpapershotgun.com/turbo-overkill-early-access-review
# index274 is Type I, format 1 - BIOTA review: an inoffensive Metroidvania that occasionally leaps to greatness: https://www.rockpapershotgun.com/biota-review
# index275 is Type I, format 1 - Chinatown Detective Agency review: stylish cyberpunk meets history homework: https://www.rockpapershotgun.com/chinatown-detective-agency-review
# index276 is Type I, format 1 - Lego Star Wars: The Skywalker Saga review: an inconsistent intergalactic collectathon: https://www.rockpapershotgun.com/lego-star-wars-the-skywalker-saga-review
# index277 is Type I, format 1 - Tiny Tina's Wonderlands review: neurotic humour and the precise gun magic you'd expect: https://www.rockpapershotgun.com/tiny-tinas-wonderlands-review
# index278 is Type I, format 1 - The Fertile Crescent review (early access): a bite-sized chunk of phenomenal RTS design: https://www.rockpapershotgun.com/the-fertile-crescent-review-early-access
# ...
# index418 is Type I, format 1 - The Sims 4 Cottage Living review: unrealistic yet ideal cottagecore: https://www.rockpapershotgun.com/the-sims-4-cottage-living-review
# index419 is Type I, format 1 - The Ascent review: a fun cyberpunk shooter that takes a while to warm up: https://www.rockpapershotgun.com/the-ascent-review
# index420 is Type I, format 1 - Chernobylite review: hardly horror, but still a strong survival roguelite: https://www.rockpapershotgun.com/chernobylite-pc-review
# index421 is Type I, format 1 - The Forgotten City review: a lean mystery that builds Rome in a day: https://www.rockpapershotgun.com/the-forgotten-city-review
# index422 is Type I, format 1 - HighFleet review: a brilliant strategy game buried under frustrations: https://www.rockpapershotgun.com/highfleet-review
# index423 is Type I, format 1 - The Great Ace Attorney Chronicles review: classic Phoenix Wright: https://www.rockpapershotgun.com/the-great-ace-attorney-chronicles-review
# index424 is Type I, format 1 - Last Stop review: half a really good Doctor Who episode: https://www.rockpapershotgun.com/last-stop-review
# index425 is Type I, format 1 - Death's Door review: a sturdy and often funny fable about death: https://www.rockpapershotgun.com/deaths-door-review
# index426 is Type I, format 1 - Cris Tales review: a beautiful JRPG that's full of heart: https://www.rockpapershotgun.com/cris-tales-review
# index427 is Type I, format 1 - Mini Motorways review: life in the fast lane: https://www.rockpapershotgun.com/mini-motorways-review
# index428 is Type I, format 1 - Monster Hunter Stories 2 review: an average time lifted by excellent combat: https://www.rockpapershotgun.com/monster-hunter-stories-2-wings-of-ruin-pc-review
# index429 is Type I, format 1 - Chicory: A Colorful Tale review: picture-perfect storytelling: https://www.rockpapershotgun.com/chicory-a-colorful-tale-review
# index430 is Type I, format 1 - No More Heroes review: without motion controls, this port loses its charm on PC: https://www.rockpapershotgun.com/no-more-heroes-pc-review
# index431 is Type I, format 1 - Cruelty Squad review: this game is too cool for me, probably: https://www.rockpapershotgun.com/cruelty-squad-review
# index432 is Type I, format 1 - Wildermyth review: it will bring you more delight than you thought possible: https://www.rockpapershotgun.com/wildermyth-review
# index433 is Type I, format 1 - Scarlet Nexus review: slick anime action with a double-edged story: https://www.rockpapershotgun.com/scarlet-nexus-review
# index434 is Type I, format 1 - Ynglet review: a delightful anti-platformer: https://www.rockpapershotgun.com/ynglet-review
# index435 is Type I, format 1 - Chivalry 2 review: a gore-soaked multiplayer battler with tons of humour: https://www.rockpapershotgun.com/chivalry-2-review
# index436 is Type I, format 1 - Minute Of Islands review: a grim world drawn in a wonderful, elegant way: https://www.rockpapershotgun.com/minute-of-islands-review
# index437 is Type I, format 1 - Slipways review: schedule-shatteringly moreish: https://www.rockpapershotgun.com/slipways-review
# index438 is Type I, format 1 - Backbone review: it's not what you expect, but hot damn is it pretty: https://www.rockpapershotgun.com/backbone-review
# index439 is Type I, format 1 - Insurmountable review: a clever roguelike about mountaineering: https://www.rockpapershotgun.com/insurmountable-review
# index440 is Type I, format 1 - Dorfromantik review (early access): German engineering to calm your mind: https://www.rockpapershotgun.com/dorfromantik-review-early-access
# index441 is Type I, format 1 - The Magnificent Trufflepigs review: the hills are alive with the sound of beeping: https://www.rockpapershotgun.com/the-magnificent-trufflepigs-review
# index442 is Type I, format 1 - Overboard review: Inkle's surprise new puzzle game is a delightful murderous farce: https://www.rockpapershotgun.com/overboard-review
# index443 is Type I, format 1 - Strangeland review: a smart, dark puzzle game that's a bit Marmite-y: https://www.rockpapershotgun.com/strangeland-review
# index444 is Type I, format 1 - Elite Dangerous: Odyssey review: https://www.rockpapershotgun.com/elite-dangerous-odyssey-review
# index445 is Type I, format 1 - Biomutant review: a solid foundation, but tries to stack too much on top: https://www.rockpapershotgun.com/biomutant-review
# index446 is Type I, format 1 - Shin Megami Tensei 3: Nocturne HD Remaster review: https://www.rockpapershotgun.com/shin-megami-tensei-3-nocturne-hd-remaster-review
# index447 is Type I, format 1 - Subnautica: Below Zero review: https://www.rockpapershotgun.com/subnautica-below-zero-review
# index448 is Type I, format 1 - Resident Evil Village review: an excellent first half: https://www.rockpapershotgun.com/resident-evil-village-review
# index449 is Type I, format 1 - NieR Replicant review: a brilliant slog I'll never play again: https://www.rockpapershotgun.com/nier-replicant-review
# index450 is Type I, format 1 - Turnip Boy Commits Tax Evasion review: the funniest game I've ever played: https://www.rockpapershotgun.com/turnip-boy-commits-tax-evasion-review
# index451 is Type I, format 1 - Outriders review: A dopamine-dispensing closed loop for your monkey brain: https://www.rockpapershotgun.com/outriders-review
# index452 is Type I, format 1 - Evil Genius 2 review: https://www.rockpapershotgun.com/evil-genius-2-review
# index453 is Type I, format 1 - Yakuza 6: The Song Of Life review: https://www.rockpapershotgun.com/yakuza-6-the-song-of-life-review
# index454 is Type I, format 1 - Spacebase Startopia review: It does exactly what it needs to: https://www.rockpapershotgun.com/spacebace-startopia-review
# index455 is Type I, format 1 - Genesis Noir review: https://www.rockpapershotgun.com/genesis-noir-review
# index456 is Type I, format 1 - It Takes Two review: A really fun way to tell a bit of a boring story: https://www.rockpapershotgun.com/it-takes-two-review
# index457 is Type I, format 1 - Loop Hero review: https://www.rockpapershotgun.com/loop-hero-review
# index458 is Type I, format 1 - Maquette review: https://www.rockpapershotgun.com/maquette-review
# index459 is Type I, format 1 - Persona 5 Strikers review: https://www.rockpapershotgun.com/persona-5-strikers-review
# index460 is Type I, format 1 - Ratropolis review: https://www.rockpapershotgun.com/ratropolis-review
# index461 is Type I, format 1 - Omori review: https://www.rockpapershotgun.com/omori-review
# index462 is Type I, format 1 - Encodya review: https://www.rockpapershotgun.com/encodya-review
# index463 is Type I, format 1 - Little Nightmares 2 review: https://www.rockpapershotgun.com/little-nightmares-2-review
# index464 is Type I, format 1 - Nioh 2: The Complete Edition review: https://www.rockpapershotgun.com/nioh-2-the-complete-edition-review
# index465 is Type I, format 1 - Atelier Ryza 2: Lost Legends & The Secret Fairy review: https://www.rockpapershotgun.com/atelier-ryza-2-lost-legends-the-secret-fairy-review
# index466 is Type I, format 1 - The Medium review: https://www.rockpapershotgun.com/the-medium-review
# index467 is Type I, format 1 - Curious Expedition 2 review: https://www.rockpapershotgun.com/curious-expedition-2-review
# index468 is Type I, format 1 - Hitman 3 review: https://www.rockpapershotgun.com/hitman-3-review
# index469 is Type I, format 7 - Cyberpunk 2077 review: https://www.rockpapershotgun.com/cyberpunk-2077-review
# index470 is Type I, format 6 - Unto The End review: https://www.rockpapershotgun.com/unto-the-end-review
# index471 is Type I, format 1 - Chronos: Before The Ashes review: https://www.rockpapershotgun.com/chronos-before-the-ashes-review
# index472 is Type I, format 7 - Haven review: https://www.rockpapershotgun.com/haven-review
# index473 is Type I, format 1 - Immortals Fenyx Rising review: https://www.rockpapershotgun.com/immortals-fenyx-rising-review
# index474 is Type I, format 7 - Empire Of Sin review: https://www.rockpapershotgun.com/empire-of-sin-review
# index475 is Type I, format 1 - Call Of Duty: Black Ops Cold War multiplayer review: https://www.rockpapershotgun.com/call-of-duty-black-ops-cold-war-multiplayer-review
# index476 is Type I, format 1 - Across The Grooves review: https://www.rockpapershotgun.com/across-the-grooves-review
# index477 is Type I, format 7 - The Falconeer review: https://www.rockpapershotgun.com/the-falconeer-review
# index478 is Type I, format 1 - Call of Duty: Black Ops Cold War singleplayer review: https://www.rockpapershotgun.com/call-of-duty-black-ops-cold-war-singleplayer-review
# index479 is Type I, format 1 - Bugsnax review: https://www.rockpapershotgun.com/bugsnax-review
# index480 is Type I, format 1 - Assassin's Creed Valhalla review: https://www.rockpapershotgun.com/assassins-creed-valhalla-review
# index481 is Type I, format 1 - Yakuza: Like A Dragon review: https://www.rockpapershotgun.com/yakuza-like-a-dragon-review
# index482 is Type I, format 1 - Teardown review: a glorious crime caper about smashing open buildings like chocolate eggs: https://www.rockpapershotgun.com/teardown-review-a-glorious-crime-caper-about-smashing-open-buildings-like-chocolate-eggs
# index483 is Type I, format 1 - Little Hope review: https://www.rockpapershotgun.com/little-hope-review
# index484 is Type I, format 1 - Watch Dogs Legion review: https://www.rockpapershotgun.com/watch-dogs-legion-review
# index485 is Type I, format 1 - ScourgeBringer review: https://www.rockpapershotgun.com/scourgebringer-review
# index486 is Type I, format 2 - Ghostrunner review: https://www.rockpapershotgun.com/ghostrunner-review
# index487 is Type I, format 1 - Disc Room review: https://www.rockpapershotgun.com/disc-room-review
# index488 is Type I, format 1 - Amnesia: Rebirth review: https://www.rockpapershotgun.com/amnesia-rebirth-review
# index489 is Type I, format 1 - Noita review: https://www.rockpapershotgun.com/noita-review
# index490 is Type II, format 3 - The ten-minute indie games of the 10mg collection reviewed in ten minutes each: https://www.rockpapershotgun.com/the-ten-minute-indie-games-of-the-10mg-collection-reviewed-in-ten-minutes-each
# index491 is Type I, format 1 - Partisans 1941 review: https://www.rockpapershotgun.com/partisans-1941-review
# index492 is Type I, format 1 - Torchlight 3 review: A disappointing and dreary return: https://www.rockpapershotgun.com/torchlight-3-review-a-disappointing-and-dreary-return
# index493 is Type I, format 1 - Space Crew review: https://www.rockpapershotgun.com/space-crew-review
# index494 is Type I, format 1 - I Am Dead review: https://www.rockpapershotgun.com/i-am-dead-review
# index495 is Type I, format 1 - Star Wars: Squadrons review: https://www.rockpapershotgun.com/star-wars-squadrons-review
# index496 is Type I, format 1 - Baldur’s Gate 3 Early Access review: https://www.rockpapershotgun.com/baldurs-gate-3-review-early-access
# index497 is Type II, format 3 - Family follow-up Rivals brings you more lovely musical detection: https://www.rockpapershotgun.com/family-follow-up-rivals-brings-you-more-lovely-musical-detection
# index498 is Type I, format 1 - The Dungeon Of Naheulbeuk review: https://www.rockpapershotgun.com/the-dungeon-of-naheulbeuk-review
# index499 is Type I, format 1 - Spelunky 2 review: a worthy successor to a classic: https://www.rockpapershotgun.com/spelunky-2-review-a-worthy-successor-to-a-classic
# index500 is Type I, format 1 - Sure, Crysis Remastered is nice, but have you ever played the original Crysis?: https://www.rockpapershotgun.com/sure-crysis-remastered-is-nice-but-have-you-ever-played-the-original-crysis
# index501 is Type I, format 1 - Pendragon review: https://www.rockpapershotgun.com/pendragon-review
# index502 is Type I, format 1 - Hades review: https://www.rockpapershotgun.com/hades-review
# index503 is Type I, format 1 - Post Void review: https://www.rockpapershotgun.com/post-void-review
# index504 is Type II, format 2 - Iron Harvest review: https://www.rockpapershotgun.com/iron-harvest-review
# index505 is Type I, format 1 - A Monster's Expedition review: https://www.rockpapershotgun.com/a-monsters-expedition-review
# index506 is Type I, format 1 - Star Renegades review: https://www.rockpapershotgun.com/star-renegades-review
# index507 is Type I, format 1 - Paradise Killer review: https://www.rockpapershotgun.com/paradise-killer-review
# index508 is Type I, format 1 - Tell Me Why review: https://www.rockpapershotgun.com/tell-me-why-review
# index509 is Type I, format 1 - Crusader Kings 3 review: https://www.rockpapershotgun.com/crusader-kings-3-review
# index510 is Type I, format 1 - Wasteland 3 review: https://www.rockpapershotgun.com/wasteland-3-review
# index511 is Type I, format 1 - No Straight Roads review: https://www.rockpapershotgun.com/no-straight-roads-review
# index512 is Type I, format 1 - Spiritfarer review: https://www.rockpapershotgun.com/spiritfarer-review
# index513 is Type I, format 1 - Mortal Shell review: https://www.rockpapershotgun.com/mortal-shell-review
# index514 is Type I, format 1 - A Total War Saga: Troy review: https://www.rockpapershotgun.com/a-total-war-saga-troy-review
# index515 is Type I, format 1 - Horizon Zero Dawn PC review: https://www.rockpapershotgun.com/horizon-zero-dawn-pc-review
# index516 is Type I, format 1 - Fight Crab review: https://www.rockpapershotgun.com/fight-crab-review
# index517 is Type I, format 1 - Maid Of Sker review: https://www.rockpapershotgun.com/maid-of-sker-review
# index518 is Type I, format 1 - Carrion review: https://www.rockpapershotgun.com/carrion-review
# index519 is Type I, format 1 - Röki review: https://www.rockpapershotgun.com/roki-review
# index520 is Type I, format 1 - Necrobarista review: https://www.rockpapershotgun.com/necrobarista-review
# index521 is Type I, format 1 - Plebby Quest: The Crusades review: https://www.rockpapershotgun.com/plebby-quest-the-crusades-review
# index522 is Type I, format 1 - Among Trees review (early access): https://www.rockpapershotgun.com/among-trees-review-early-access
# index523 is Type I, format 1 - Hardspace: Shipbreaker review (early access): https://www.rockpapershotgun.com/hardspace-shipbreaker-review-early-access
# index524 is Type I, format 1 - Persona 4 Golden review: https://www.rockpapershotgun.com/persona-4-golden-review
# index525 is Type I, format 1 - Griftlands review (early access): https://www.rockpapershotgun.com/griftlands-review
# index526 is Type I, format 1 - Disintegration review: https://www.rockpapershotgun.com/disintegration-review
# index527 is Type I, format 1 - Main Assembly review (early access): https://www.rockpapershotgun.com/main-assembly-review-early-access
# index528 is Type I, format 1 - Beyond Blue review: https://www.rockpapershotgun.com/beyond-blue-review
# index529 is Type I, format 1 - Desperados 3 review: https://www.rockpapershotgun.com/desperados-3-review
# index530 is Type I, format 1 - Space Haven review (early access): https://www.rockpapershotgun.com/space-haven-review-early-access
# index531 is Type I, format 1 - The Sims 4 Eco Lifestyle review: https://www.rockpapershotgun.com/the-sims-4-eco-lifestyle-review
# index532 is Type I, format 1 - Command & Conquer Remastered Collection review: https://www.rockpapershotgun.com/command-conquer-remastered-collection-review
# index533 is Type I, format 1 - Satisfactory review (early access): https://www.rockpapershotgun.com/satisfactory-review-early-access
# index534 is Type I, format 1 - Monster Train review: https://www.rockpapershotgun.com/monster-train-review
# index535 is Type I, format 1 - Quantum League review (early access): https://www.rockpapershotgun.com/quantum-league-review-early-access
# index536 is Type I, format 1 - Old World review (early access): https://www.rockpapershotgun.com/old-world-review-early-access
# index537 is Type I, format 1 - Valorant review: https://www.rockpapershotgun.com/valorant-review
# index538 is Type I, format 1 - Poly Bridge 2 review: https://www.rockpapershotgun.com/poly-bridge-2-review
# index539 is Type I, format 1 - Nimbatus review: https://www.rockpapershotgun.com/nimbatus-review

# %% [markdown]
# * note that the above code is designed to run all dataset (2386), while 10 formats are still not able to cover all the variation for all 2386 dataset and minor adjustments to code might be needed to extract all the information correctly (due to limited timeframe, other formats need to be handled with extra time), it is more than enough to extract all recent three years reviews & related information correctly.

# %% [markdown]
# #### 4. Clean & Store the extracted dataset to local JSON file
# The result is store in json file `game_reviews_rps_in_recent_years.json`

# %%
# uisng regex to check if the first or the last character of the title is ':' or ' ' or '<br>' or '<br/>'
# regex tested using regex101
# ChatGpt used here to debug and fix regex 
def remove_weird_character(text):r'^[:\s<br>]+|[:\s<br/>]+$'
    pattern = re.compile(r'^[:\s<br>]+|[:\s<br/>]+$')
    if pattern.search(text):
        text = pattern.sub('', text)
    return text

# %%
merged_dict = {}
rps_data = []

for i in range(0, len(reviews_in_recent_years)):
    merged_dict = {
        'Title': reviews_in_recent_years[i]['Title'],
        'URL': reviews_in_recent_years[i]['URL'],
        'Game Title': game_titles[i],
        'Developer': remove_weird_character(developers[i].replace("\n", "")),
        'Labels': ", ".join(labels[i]), # convert list to str for csv
        'Brief': remove_weird_character(briefs[i]),
        'Review': reviews[i]['review'].replace("\n", "").replace("\r", ""), # remove all newlines for further processing
        'Publish Date': dates[i]
    }
    rps_data.append(merged_dict)

# %%
with open('game_reviews_rps_in_recent_years.json', 'w') as output:
    json.dump(rps_data, output)

# %% [markdown]
# ### References

# %% [markdown]
# Tools used in this notebook:
#
# - Simplescraper, a Chrome Extension to obtain HTML elements for the select content on any website. Available at: https://simplescraper.io
#
# - regex101, regular expression tester. Available at: https://regex101.com/
#
# Code References:
#
# - Using Python datetime.strptime [online] Stack Overflow. Available at: https://stackoverflow.com/questions/72702859/use-python-datetime-strptime
#
# - Python Exception Handling [online] Programiz. Available at: https://www.programiz.com/python-programming/exception-handling
